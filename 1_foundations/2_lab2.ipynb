# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine a remote island community of 10,000 people whose freshwater supply is currently 60% groundwater (abstraction wells) and 40% a seasonal river; sea-level rise and saltwater intrusion are projected to reduce usable groundwater by 50% over 10 years, the island has a fixed annual budget of $20M for infrastructure and social programs, access to solar and wind resources sufficient to generate up to 15 MW, limited arable land, and a fishing industry providing 30% of dietary protein—you're advising the community council: provide (a) a prioritized, costed 10-year adaptation plan with concrete milestones and clear contingencies, including at least three alternative strategies if key assumptions change; (b) quantitative estimates of costs, benefits, and risks (with ranges and approximate probabilities) for each major action; (c) an explicit list of assumptions and how each would be empirically tested or monitored; (d) identification of cognitive biases, institutional failure modes, or socio-political obstacles that could derail the plan and mitigation measures for each; (e) a concise 100-word public summary to persuade skeptical residents of the plan's necessity and fairness; and (f) a transparent explanation of the chain of reasoning you used, with explicit points where your analysis is uncertain or likely to be wrong—what do you propose and why?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Here is a structured, action-focused plan you can adapt for the council. I’ve bundled it to fit the island’s water-energy-food nexus, budget, and social context, with clear milestones, contingencies, and risk management.
#
# (a) Prioritized, costed 10-year adaptation plan (milestones, contingencies, and three alternative strategies)
#
# Strategic pillars
# - Water security and resilience (reduce groundwater vulnerability; diversify supply)
# - Energy resilience (renewables-based microgrid; reliable pumping and storage)
# - Food security and nutrition (increase local protein and staples; reduce import risk)
# - Infrastructure, governance, and risk monitoring (trusted, transparent, adaptive)
#
# Year-by-year actions (highlights; budget: total ≈ $150–190M over 10 years; annual capex ≈ $20M, plus a contingency fund)
#
# 1) Water security: demand, supply, and protection
# - Action W1. Water demand management and leakage reduction
#   - What: audit current use, fix leaks, fix inefficient fixtures, public water-use campaign; pricing signals optional but transparent.
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: baseline water use; 15–25% reduction in per-capita use by Year 2; 10–15% reduction in non-revenue water
#   - Contingencies: if savings underperform, escalate with stricter water-use rules and incentives
#   - Risks/uncertainties: public opposition to restrictions; mitigation with inclusive planning and compensation for hardship
#
# - Action W2. Desalination and/or seawater intrusion barriers (modular approach)
#   - What: deploy 1–2 small modular desalination units (target 1.5–2.5 million L/day) powered by solar/wind; consider brine management; staged expansion to meet demand if groundwater declines faster.
#   - Timeline: Year 1–3 initial units; Year 4–5 scale-up if needed
#   - Cost: $40–65M (including energy integration and storage interfaces)
#   - Milestones: unit commissioning; supply meets 40–60% of peak demand in dry season by Year 3; expansion to 70–80% by Year 5 if groundwater declines faster
#   - Contingencies: if desalination costs or operations are higher-than-expected, rely more on rainwater harvesting and river recharge
#   - Risks/uncertainties: energy supply reliability; brine disposal impacts; mitigation with robust monitoring and guaranteed maintenance contracts
#
# - Action W3. Rainwater harvesting and storage improvements
#   - What: retrofit roofs/municipal facilities; build above-ground storage and infiltration basins; treat and reuse graywater where feasible
#   - Timeline: Year 1–4
#   - Cost: $5–12M
#   - Milestones: capture capacity added to 10–20% of demand by Year 4
#   - Contingencies: if rainfall is less than expected, prioritize urban harvesting and in-building storage
#   - Risks/uncertainties: climate variability; mitigation with diversified sources
#
# - Action W4. Groundwater protection and managed aquifer recharge (if aquifer present)
#   - What: monitor salinity and levels; create recharge basins using treated water or captured rain; regulate abstraction to sustainable yield
#   - Timeline: Year 1–Year 6 (steady progress)
#   - Cost: $20–30M
#   - Milestones: establish baseline salinity/levels; implement managed yield target; regular reporting
#   - Contingencies: scale-back if aquifer proves less viable; reallocate to W1–W3
#   - Risks/uncertainties: effectiveness of recharge; governance of water rights
#
# - Action W5. Water monitoring, quality, and governance
#   - What: install continuous water-quality sensors; create data dashboards; public annual reports; independent technical oversight
#   - Timeline: Year 1–Year 2 (setup); ongoing
#   - Cost: $3–6M
#   - Milestones: real-time data feeds; quarterly performance reviews
#   - Risks/uncertainties: data reliability; mitigation with redundancy and third-party QA
#
# 2) Energy resilience: renewables, storage, and reliable pumping
# - Action E1. Solar-wwind microgrid with storage (staged)
#   - What: install 5–7 MW initial renewable capacity; add storage to balance pumping and peak demand; create island-wide microgrid with islanded operation capability
#   - Timeline: Year 1–3 (initial); Year 4–6 expansion
#   - Cost: $30–60M (initial; total may reach $60–90M with storage expansion)
#   - Milestones: 24/7 pumping reliability for water system in dry season by Year 3; >80% daytime energy from renewables; storage sufficiency during outages
#   - Contingencies: if capital costs or maintenance rise, defer some capacity and use more targeted battery storage; otherwise add diesel-free back-up
#   - Risks/uncertainties: resource variability; storage cost and lifecycle; mitigation with modular installs and long-term O&M contracts
#
# - Action E2. Energy efficiency and demand-side management for pumps and public buildings
#   - What: high-efficiency pumps, VFDs, smart controls; seasonally adjusted pumping schedules
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: pump efficiency improvements; energy-use reductions of 15–30% in water pumping by Year 2
#   - Risks/uncertainties: device performance; mitigation with manufacturer warranties and local training
#
# - Action E3. Contingent backup planning and fuel resilience
#   - What: limited diesel backup only if renewables+storage cannot meet demand; negotiate fuel supply contracts with price hedges
#   - Timeline: Year 1–10
#   - Cost: $5–10M contingency and standby reserves
#   - Milestones: fuel-on-hand policy; defined trigger for backup usage
#   - Risks/uncertainties: fuel price spikes; mitigation by prioritizing energy resilience
#
# 3) Food security and nutrition: protein and staple supply
# - Action F1. Aquaponics greenhouses and selected high-protein crops
#   - What: build 1–2 compact aquaponics facilities; grow fish (e.g., tilapia) and leafy veggies; optimize water reuse
#   - Timeline: Year 2–4
#   - Cost: $8–12M
#   - Milestones: first harvest Year 3; target protein contribution increased by 5–15% of dietary protein by Year 5
#   - Benefits: local protein, reduced import bill, year-round production
#   - Risks/uncertainties: technology uptake, fish disease; mitigation with training and biosecurity plans
#
# - Action F2. Small-scale, low-footprint animal protein/alternative proteins
#   - What: pilot programs (insect protein, poultry, or other adaptable options) where feasible
#   - Timeline: Year 3–5
#   - Cost: $2–5M
#   - Milestones: pilot success; upscaling if feasible
#   - Risks: market acceptance; mitigation with community engagement
#
# - Action F3. Fisheries productivity and post-harvest improvements
#   - What: promote sustainable fishing practices, reduce post-harvest losses, cold-chain improvements for local markets
#   - Timeline: Year 1–5
#   - Cost: $3–5M
#   - Milestones: reduced spoilage; stable protein supply at community level
#   - Risks: enforcement challenges; mitigation with training and community-led governance
#
# 4) Governance, risk monitoring, and social equity
# - Action G1. Independent governance and participatory planning
#   - What: citizen assemblies, independent watchdog, transparent budgeting, open data
#   - Timeline: Year 1–10 (ongoing)
#   - Cost: $3–6M
#   - Milestones: annual public dashboards; independent audit each year
#   - Risks/mitigations: risk of capture; mitigate with rotating mandates and clear conflict-of-interest rules
#
# - Action G2. Early warning, climate risk monitoring, and adaptation feedback loops
#   - What: hazard warning system (storm surge, salt intrusion, drought), community alert networks
#   - Timeline: Year 1–3, ongoing
#   - Cost: $2–4M
#   - Milestones: functioning alerts; 24–48h notification windows for residents
#   - Risks: alert fatigue; mitigate with targeted segments and clear action guidelines
#
# - Action G3. Workforce training and local enterprise
#   - What: training programs for operation, maintenance, and local procurement; foster local service capacity
#   - Timeline: Year 1–10, ongoing
#   - Cost: $2–5M
#   - Milestones: local capacity indicators; increase in local maintenance jobs
#
# Cross-cutting contingency fund
# - Contingency fund: reserve 10–15% of total plan cost to cover overruns, price shocks, or faster-than-expected climate impacts.
#
# Overall timing and sequencing
# - Years 1–2: establish governance, data baseline, implement W1 (demand management), start W2 modular desalination pilots, begin E2/ E3 efficiency measures, begin F1 aquaponics pilot, start G1 governance and risk monitoring.
# - Years 3–5: scale W2 units if needed; expand W3 rainwater capture; deploy most of E1 solar+storage; broaden F1; advance G2 and G3; introduce F2/Pilot as feasible.
# - Years 6–10: stabilize W1/W2/W3; broaden E1/E2 to meet full demand; complete W4 recharge; scale up F1-3; ensure robust governance and transparent evaluation.
#
# Three alternative strategies if key assumptions change
# - Alternative A (groundwater decline slower than expected): de-emphasize large aquifer recharge timing; reallocate some W2 capacity to additional rainwater harvesting, efficiency, and river management; defer some desalination expansion until demand grows.
# - Alternative B (renewable energy generation or storage costs/availability higher than planned): prioritize aggressive energy efficiency (E2) and demand-side management; seek regional grid connections or borrow-to-invest for a staged, lower-capital renewables build; keep diesel backup as a last resort with hedging.
# - Alternative C (land and protein constraints tighten): accelerate aquaculture/prawn/seaweed options, intensify aquaponics, and expand fisheries value-chain investments; diversify protein supply beyond fish and crops; invest in protein-import efficiency (logistics and shelf life) while minimizing waste.
#
# (b) Quantitative estimates of costs, benefits, and risks (major actions)
#
# Note: all figures are rough, order-of-magnitude estimates, with ranges to reflect uncertainty. Probabilities are approximate and not guarantees.
#
# - W1. Demand management and leakage reduction
#   - Cost: $5–10M
#   - Benefits: 15–25% reduction in per-capita water use by Year 2; local water security improved; annual avoided groundwater pumping cost variable (depends on electricity and pumping cost)
#   - Risk/uncertainty: 0.2–0.4 risk of noncompliance, mitigated by community engagement
#   - Probability of achieving target: 0.6–0.8
#
# - W2. Desalination units + storage
#   - Cost: $40–65M (initial + expansion)
#   - Benefits: meets 40–80% of dry-season demand by Year 3; reduces salt intrusion risk; more reliable water supply
#   - Risk/uncertainty: 0.25–0.5
#   - Probability of achieving target: 0.6–0.8
#
# - W3. Rainwater harvesting and storage
#   - Cost: $5–12M
#   - Benefits: 10–20% of demand captured by Year 4; climate resilience
#   - Risk/uncertainty: 0.2–0.4
#   - Probability of achieving target: 0.6–0.7
#
# - W4. Groundwater management and recharge
#   - Cost: $20–30M
#   - Benefits: improved aquifer sustainability; salinity stabilization
#   - Risk/uncertainty: 0.3–0.5
#   - Probability of achieving target: 0.5–0.7
#
# - E1. Solar-wind microgrid with storage
#   - Cost: $30–90M (depending on scale and storage)
#   - Benefits: 24/7 pumping capability with high renewable share; lower fuel exposure
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - E2. Efficiency and demand management
#   - Cost: $5–10M
#   - Benefits: 15–30% reduction in pumping electricity by Year 2
#   - Risk/uncertainty: 0.2–0.3
#   - Probability of achieving target: 0.7–0.85
#
# - F1. Aquaponics greenhouse
#   - Cost: $8–12M
#   - Benefits: 5–15% of dietary protein by Year 5; year-round vegetable supply
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - F2/F3. Additional protein and fisheries improvements
#   - Cost: $5–8M
#   - Benefits: protein diversification; reduced waste
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.5–0.7
#
# - G1–G3. Governance, monitoring, training
#   - Cost: $5–10M total
#   - Benefits: higher plan fidelity; reduced governance risk
#   - Risk/uncertainty: 0.15–0.25
#   - Probability of achieving target: 0.75–0.9
#
# Contingency fund
# - 10–15% of total plan cost reserved for overruns, price spikes, or faster-than-expected climate impacts. This reduces the likelihood that a single shock derails the plan.
#
# Net impact expectations (illustrative)
# - Water security: major reduction in drought risk; more predictable water supply; groundwater decline mitigated when combined with W2–W4.
# - Energy: more reliable pumping for water and households; reduced fossil fuel exposure; gradual transition to renewables.
# - Food and nutrition: increased local protein and staples; reduced dietary risk if fishing catches fluctuate.
# - Social: improved public trust via transparency; better local job opportunities and skills development.
#
# (c) Assumptions and monitoring plan (how each assumption would be empirically tested)
#
# Key assumptions and tests
# - A1. Groundwater usable volume declines by 50% over 10 years due to saltwater intrusion/seawater intrusion.
#   - Test/monitor: quarterly groundwater salinity and level measurements at multiple wells; annual aquifer yield estimates; publish annual trend reports.
# - A2. River is seasonal but provides reliable wet-season supply.
#   - Test/monitor: river flow and seasonal discharge records; correlate with rainfall data; test with hydrological model updates annually.
# - A3. Renewable resources can reliably supply up to 15 MW (ratio of capacity factor to demand acceptable for pumping and household loads).
#   - Test/monitor: track solar/wind capacity factor, storage state-of-charge, and grid reliability; conduct quarterly reliability assessments.
# - A4. The budget remains fixed at $20M/year with no major fiscal shocks.
#   - Test/monitor: annual budget reviews; scenario analyses for cost overruns; publish quarterly expenditure reports.
# - A5. Fishing provides ~30% of dietary protein; aquaculture/alternate proteins will contribute meaningfully.
#   - Test/monitor: track dietary protein sources; monitor fish catch, aquaculture yields, and imports; adjust plans if reliance shifts.
# - A6. Land is limited but amenable to rainfed or controlled-environment agriculture.
#   - Test/monitor: land-use assessments; crop yields; soil and water quality tests for greenhouse operations.
# - A7. Local institutions can implement and maintain new systems with training.
#   - Test/monitor: track maintenance logs, training take-up, and operator certifications; independent audits.
#
# Monitoring framework
# - Establish a 3-year baseline for water demand, groundwater quality, renewable generation, and protein supply.
# - Quarterly public dashboards and annual independent audit.
# - Use scenario planning with annual updates (best-case, base-case, worst-case).
# - Independent technical advisor panel with rotating membership and conflict-of-interest safeguards.
# - Public engagement sessions after major milestones; adjust plan in response to feedback.
#
# (d) Cognitive biases, institutional failure modes, or socio-political obstacles and mitigation
#
# Biases and plan fragility
# - Optimism bias (overestimating benefits, underestimating costs)
#   - Mitigation: require independent external reviews; set “stop gates” at key milestones to reassess before scale-up.
# - Planning fallacy and sunk cost (continuing projects despite evidence of poor performance)
#   - Mitigation: implement mandatory mid-course corrections; predefine exit or pivot criteria; keep a scalable option inventory.
# - Anchoring to historical water/energy costs and patterns
#   - Mitigation: use multiple scenario analyses (low/high demand, climate extremes); revisit assumptions annually.
# - Availability heuristic (relying on recent events)
#   - Mitigation: formal risk register with probabilistic risk estimates; stress tests for extreme months/seasons.
# - Overconfidence in technology performance
#   - Mitigation: pilot testing, staged deployments, strict reliability targets, and contingency storage/backups.
# - Equity and social justice blind spots
#   - Mitigation: inclusive planning; targeted outreach to low-income households; ensure affordable access to water, energy, and food.
#
# Institutional and socio-political obstacles
# - Interagency coordination failures or siloed authorities
#   - Mitigation: a formal cross-agency steering committee with clear decision rights; shared data platforms.
# - Political economy capture by powerful groups (fisheries, landowners)
#   - Mitigation: independent oversight, transparent procurement, community representation, and performance-based funding.
# - Public trust and engagement gaps
#   - Mitigation: early and ongoing transparent communications; public dashboards; participatory budgeting options.
# - Funding volatility and macroeconomic shocks
#   - Mitigation: contingency fund; staged financing; explore external grants and concessional loans with clear milestones.
# - Workforce and capability gaps
#   - Mitigation: robust training, apprenticeships, and local job guarantees; partner with regional centers of excellence.
#
# (e) Public communication: concise 100-word summary (for skeptical residents)
#
# Text (exact 100 words)
# To protect water, food, and energy for our 10,000 residents over the next decade, we will invest in a diversified, reef-to-ridge resilience plan. We will reduce dependence on groundwater by expanding renewable-powered desalination, rainwater capture, and efficient water use; we will secure affordable, reliable electricity with a solar-wind microgrid and storage; we will boost local food by supporting aquaponics and fisheries improvements; we will strengthen governance, warning systems, and jobs through training and shared decision making. The plan uses our $20M/year budget, with transparent milestones and contingencies if conditions change. It aims fairness, jobs, and a safer island future together.
#
# (f) Transparent explanation of chain-of-reasoning and uncertainty points
#
# Chain-of-reasoning (high level)
# - Step 1: Define the system boundaries (water-energy-food nexus) and list constraints (10k people, $20M/year, 15 MW renewables potential, limited arable land, 30% protein from fishing).
# - Step 2: Identify the central risk drivers: groundwater decline, seasonal river reliability, energy reliability, protein supply, and governance capacity.
# - Step 3: Develop a portfolio of actions targeting water reliability, energy resilience, food security, and governance, each with milestones, costs, and risk controls.
# - Step 4: Prioritize actions by payoffs (water reliability and energy security for the population; strong governance to steer execution) and by feasibility under budget.
# - Step 5: Build contingencies for key assumption changes (groundwater decline rate; renewables costs; protein supply dynamics).
# - Step 6: Establish monitoring, independent oversight, and adaptive management so the plan can be revised in light of data.
#
# Uncertainty points and where the plan is likely to misestimate
# - Rate of groundwater decline (A1) and groundwater management effectiveness
#   - Risk: too-optimistic persistence of aquifer; plan must adjust W2/W3 emphasis if salinity or yield changes
# - Costs and performance of desalination and storage (W2)
#   - Risk: unit costs, energy needs, and maintenance could be higher; contingency and staged expansion help
# - Renewable energy performance and storage costs (E1)
#   - Risk: actual capacity factor and storage costs may diverge; plan relies on milestoned pilots and upgrades
# - Protein supply dynamics (F1–F3)
#   - Risk: aquaponics uptake, disease, or market acceptance could lag; alternative proteins and fisheries improvements provide backup
# - Governance and social acceptance
#   - Risk: delays in adoption, public distrust; mitigations include transparent dashboards and participatory processes
#
# If any of these uncertainties become dominant, the plan includes three alternative strategy packages (A, B, C) as described in section (a).
#
# Why this plan, and why now
# - It directly addresses the nexus of water, energy, and food with a diversified, modular, and costed approach that reduces risk exposure to any single resource or shock.
# - It uses the fixed annual budget to build resilience progressively, with milestones and independent oversight to maintain trust.
# - It anticipates potential changes in climate, technology, and social dynamics through explicit contingencies and alternative pathways.
#
# Notes for implementation
# - Start with a robust data baseline: water use, groundwater quality and levels, river flows, renewable resource assessments, and protein supply patterns.
# - Establish an independent monitoring and governance unit early, with transparent reporting.
# - Engage communities continuously to align priorities, distribute benefits, and maintain legitimacy.
#
# If you’d like, I can tailor the cost estimates to your island’s actual unit costs (labor, materials, fuel, maintenance), or draft a one-page dashboard (metrics, targets, and timelines) for council review.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "gemma3:4b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Okay, this is a complex challenge – a classic climate adaptation scenario demanding a nuanced and robust response. Here's my advisory plan, integrating the requested components, acknowledging uncertainties and incorporating a pragmatic, phased approach.
#
# **(a) Prioritized, Costed 10-Year Adaptation Plan**
#
# **Phase 1 (Years 1-3): Stabilization & Data Gathering ($6M)**
# * **Milestone 1:** Comprehensive Hydrogeological Survey - ($500k, 12 months) - Detailed mapping of aquifer recharge rates, salinity intrusion levels, and remaining groundwater potential.  Probability of success: 90% (based on existing data), risk mitigation: secondary surveys.
# * **Milestone 2:** River Water Management System Upgrade – ($1M, 18 months) – Repairing erosion control, improved diversion/storage, and water quality monitoring.
# * **Milestone 3:** Initial Solar/Wind Integration – ($2.5M, 24 months) – Installation of 5 MW solar/wind to power initial water purification.
#
# **Phase 2 (Years 4-7): Diversification & Resilience ($10M)**
# * **Milestone 4:**  Desalination Plant (1 MW) – ($4M, 36 months) – Initial pilot testing, expanded capacity based on water demand.  Contingency: If desalination proves too expensive, focus shifts to rainwater harvesting.
# * **Milestone 5:** Crop Diversification & Aquaponic Systems - ($2M, 36 months) – Implementing drought-resistant crops, establishing small-scale aquaponic farms.
# * **Milestone 6:**  Community Water Storage & Distribution ($2M, 36 months) – Building elevated storage tanks, improving distribution networks using renewable energy.
#
# **Phase 3 (Years 8-10): Long-Term Security & Adaptive Management ($4M)**
# * **Milestone 7:**  Second Desalination Plant (2 MW) – ($2.5M, 48 months) –Scaling up desal as saltwater intrusion worsens.
# * **Milestone 8:**  Climate Modelling & Research ($1M, 60 months) – Ongoing monitoring, research into alternative water sources & adaptation techniques.
#
#
#
# **(b) Quantitative Estimates (Ranges & Probabilities)**
#
# | Action                   | Cost (USD)   | Benefit (Water Availability - m3/year) | Risk (Probability, % ) | Benefit Probability |
# |---------------------------|---------------|---------------------------------------|-----------------------|-----------------------|
# | Hydrogeological Survey    | $500k          | N/A                                  | 10                      | 90%                    |
# | River Upgrade             | $1M           | 200,000                             | 20                     | 70%                    |
# | Solar/Wind Integration     | $2.5M         | N/A                                  | 5                      | 85%                    |
# | Desalination (1MW)        | $4M           | 1,500,000                             | 30                     | 60%                    |
# | Desalination (2MW)        | $2.5M         | 4,500,000                             | 40                     | 50%                    |
# | Crop Diversification       | $2M           | 50,000                               | 40                     | 75%                    |
# | Water Storage & Distribution| $2M           | 100,000                             | 25                     | 80%                    |
# | Climate Research          | $1M           | N/A                                  | 15                      | 95%                    |
#
# **(c) Assumptions & Monitoring**
#
# * **Sea-Level Rise:** Assumed to be 0.5m rise over 10 years (based on IPCC projections).  *Testing:* Monthly sea-level monitoring with tide gauges.
# * **Groundwater Recharge:**  Recharge rates are moderately stable. *Testing:* Continuous aquifer monitoring – water levels, salinity, and flow rates.
# * **Solar/Wind Output:**  Consistent renewable energy generation. *Testing:* Real-time monitoring of generation, with backup generator ready.
#
#
# **(d) Cognitive Biases & Mitigation**
#
# * **Confirmation Bias:** Prioritizing data supporting the desalination plan.  *Mitigation:* Structured, multidisciplinary assessment panel.
# * **Status Quo Bias:** Resistance to change and new technologies. *Mitigation:* Extensive community engagement, demonstration projects.
# * **Bandwagon Effect:**  Everyone rushes to invest in desalination; leads to inflated costs. *Mitigation:*  Procurement process with transparent bidding, independent expert reviews.
#
# **(e) Public Summary (100 Words)**
#
# "Our island faces a serious challenge: rising seas threaten our freshwater. This plan isn't just about surviving; it’s about securing our future. We’ll combine smarter water management with sustainable solutions like solar and aquaponics.  This initial $20M investment, built from a mix of funds, isn’t a cost but an insurance policy for our community’s health, food security, and prosperity using proven technologies, ensuring our island thrives for generations to come."
#
# **(f) Chain of Reasoning & Uncertainties**
#
# I'm heavily reliant on the sea-level rise prediction (0.5m), which has vast uncertainty.  My primary analysis assumes a relatively stable groundwater recharge rate, which could be significantly affected by climate-induced changes to rainfall patterns. The success of solar/wind integration hinges on consistent resource availability—a risk addressed with battery storage. My confidence in desalination’s affordability and long-term operation is moderate, based on the relatively untested technology – therefore, phased investment is key. The biggest risk is a "black swan" event – a significantly accelerated sea-level rise or a catastrophic failure of core infrastructure.
#
#
#
# Do you want me to elaborate on any particular aspect, refine the plan, or assess a specific risk in more detail?  Let me know how I can help you further!

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'gemma3:4b']
# ['Here is a structured, action-focused plan you can adapt for the council. I’ve bundled it to fit the island’s water-energy-food nexus, budget, and social context, with clear milestones, contingencies, and risk management.\n\n(a) Prioritized, costed 10-year adaptation plan (milestones, contingencies, and three alternative strategies)\n\nStrategic pillars\n- Water security and resilience (reduce groundwater vulnerability; diversify supply)\n- Energy resilience (renewables-based microgrid; reliable pumping and storage)\n- Food security and nutrition (increase local protein and staples; reduce import risk)\n- Infrastructure, governance, and risk monitoring (trusted, transparent, adaptive)\n\nYear-by-year actions (highlights; budget: total ≈ $150–190M over 10 years; annual capex ≈ $20M, plus a contingency fund)\n\n1) Water security: demand, supply, and protection\n- Action W1. Water demand management and leakage reduction\n  - What: audit current use, fix leaks, fix inefficient fixtures, public water-use campaign; pricing signals optional but transparent.\n  - Timeline: Year 1–2\n  - Cost: $5–10M\n  - Milestones: baseline water use; 15–25% reduction in per-capita use by Year 2; 10–15% reduction in non-revenue water\n  - Contingencies: if savings underperform, escalate with stricter water-use rules and incentives\n  - Risks/uncertainties: public opposition to restrictions; mitigation with inclusive planning and compensation for hardship\n\n- Action W2. Desalination and/or seawater intrusion barriers (modular approach)\n  - What: deploy 1–2 small modular desalination units (target 1.5–2.5 million L/day) powered by solar/wind; consider brine management; staged expansion to meet demand if groundwater declines faster.\n  - Timeline: Year 1–3 initial units; Year 4–5 scale-up if needed\n  - Cost: $40–65M (including energy integration and storage interfaces)\n  - Milestones: unit commissioning; supply meets 40–60% of peak demand in dry season by Year 3; expansion to 70–80% by Year 5 if groundwater declines faster\n  - Contingencies: if desalination costs or operations are higher-than-expected, rely more on rainwater harvesting and river recharge\n  - Risks/uncertainties: energy supply reliability; brine disposal impacts; mitigation with robust monitoring and guaranteed maintenance contracts\n\n- Action W3. Rainwater harvesting and storage improvements\n  - What: retrofit roofs/municipal facilities; build above-ground storage and infiltration basins; treat and reuse graywater where feasible\n  - Timeline: Year 1–4\n  - Cost: $5–12M\n  - Milestones: capture capacity added to 10–20% of demand by Year 4\n  - Contingencies: if rainfall is less than expected, prioritize urban harvesting and in-building storage\n  - Risks/uncertainties: climate variability; mitigation with diversified sources\n\n- Action W4. Groundwater protection and managed aquifer recharge (if aquifer present)\n  - What: monitor salinity and levels; create recharge basins using treated water or captured rain; regulate abstraction to sustainable yield\n  - Timeline: Year 1–Year 6 (steady progress)\n  - Cost: $20–30M\n  - Milestones: establish baseline salinity/levels; implement managed yield target; regular reporting\n  - Contingencies: scale-back if aquifer proves less viable; reallocate to W1–W3\n  - Risks/uncertainties: effectiveness of recharge; governance of water rights\n\n- Action W5. Water monitoring, quality, and governance\n  - What: install continuous water-quality sensors; create data dashboards; public annual reports; independent technical oversight\n  - Timeline: Year 1–Year 2 (setup); ongoing\n  - Cost: $3–6M\n  - Milestones: real-time data feeds; quarterly performance reviews\n  - Risks/uncertainties: data reliability; mitigation with redundancy and third-party QA\n\n2) Energy resilience: renewables, storage, and reliable pumping\n- Action E1. Solar-wwind microgrid with storage (staged)\n  - What: install 5–7 MW initial renewable capacity; add storage to balanc ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Here is a structured, action-focused plan you can adapt for the council. I’ve bundled it to fit the island’s water-energy-food nexus, budget, and social context, with clear milestones, contingencies, and risk management.
#
# (a) Prioritized, costed 10-year adaptation plan (milestones, contingencies, and three alternative strategies)
#
# Strategic pillars
# - Water security and resilience (reduce groundwater vulnerability; diversify supply)
# - Energy resilience (renewables-based microgrid; reliable pumping and storage)
# - Food security and nutrition (increase local protein and staples; reduce import risk)
# - Infrastructure, governance, and risk monitoring (trusted, transparent, adaptive)
#
# Year-by-year actions (highlights; budget: total ≈ $150–190M over 10 years; annual capex ≈ $20M, plus a contingency fund)
#
# 1) Water security: demand, supply, and protection
# - Action W1. Water demand management and leakage reduction
#   - What: audit current use, fix leaks, fix inefficient fixtures, public water-use campaign; pricing signals optional but transparent.
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: baseline water use; 15–25% reduction in per-capita use by Year 2; 10–15% reduction in non-revenue water
#   - Contingencies: if savings underperform, escalate with stricter water-use rules and incentives
#   - Risks/uncertainties: public opposition to restrictions; mitigation with inclusive planning and compensation for hardship
#
# - Action W2. Desalination and/or seawater intrusion barriers (modular approach)
#   - What: deploy 1–2 small modular desalination units (target 1.5–2.5 million L/day) powered by solar/wind; consider brine management; staged expansion to meet demand if groundwater declines faster.
#   - Timeline: Year 1–3 initial units; Year 4–5 scale-up if needed
#   - Cost: $40–65M (including energy integration and storage interfaces)
#   - Milestones: unit commissioning; supply meets 40–60% of peak demand in dry season by Year 3; expansion to 70–80% by Year 5 if groundwater declines faster
#   - Contingencies: if desalination costs or operations are higher-than-expected, rely more on rainwater harvesting and river recharge
#   - Risks/uncertainties: energy supply reliability; brine disposal impacts; mitigation with robust monitoring and guaranteed maintenance contracts
#
# - Action W3. Rainwater harvesting and storage improvements
#   - What: retrofit roofs/municipal facilities; build above-ground storage and infiltration basins; treat and reuse graywater where feasible
#   - Timeline: Year 1–4
#   - Cost: $5–12M
#   - Milestones: capture capacity added to 10–20% of demand by Year 4
#   - Contingencies: if rainfall is less than expected, prioritize urban harvesting and in-building storage
#   - Risks/uncertainties: climate variability; mitigation with diversified sources
#
# - Action W4. Groundwater protection and managed aquifer recharge (if aquifer present)
#   - What: monitor salinity and levels; create recharge basins using treated water or captured rain; regulate abstraction to sustainable yield
#   - Timeline: Year 1–Year 6 (steady progress)
#   - Cost: $20–30M
#   - Milestones: establish baseline salinity/levels; implement managed yield target; regular reporting
#   - Contingencies: scale-back if aquifer proves less viable; reallocate to W1–W3
#   - Risks/uncertainties: effectiveness of recharge; governance of water rights
#
# - Action W5. Water monitoring, quality, and governance
#   - What: install continuous water-quality sensors; create data dashboards; public annual reports; independent technical oversight
#   - Timeline: Year 1–Year 2 (setup); ongoing
#   - Cost: $3–6M
#   - Milestones: real-time data feeds; quarterly performance reviews
#   - Risks/uncertainties: data reliability; mitigation with redundancy and third-party QA
#
# 2) Energy resilience: renewables, storage, and reliable pumping
# - Action E1. Solar-wwind microgrid with storage (staged)
#   - What: install 5–7 MW initial renewable capacity; add storage to balance pumping and peak demand; create island-wide microgrid with islanded operation capability
#   - Timeline: Year 1–3 (initial); Year 4–6 expansion
#   - Cost: $30–60M (initial; total may reach $60–90M with storage expansion)
#   - Milestones: 24/7 pumping reliability for water system in dry season by Year 3; >80% daytime energy from renewables; storage sufficiency during outages
#   - Contingencies: if capital costs or maintenance rise, defer some capacity and use more targeted battery storage; otherwise add diesel-free back-up
#   - Risks/uncertainties: resource variability; storage cost and lifecycle; mitigation with modular installs and long-term O&M contracts
#
# - Action E2. Energy efficiency and demand-side management for pumps and public buildings
#   - What: high-efficiency pumps, VFDs, smart controls; seasonally adjusted pumping schedules
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: pump efficiency improvements; energy-use reductions of 15–30% in water pumping by Year 2
#   - Risks/uncertainties: device performance; mitigation with manufacturer warranties and local training
#
# - Action E3. Contingent backup planning and fuel resilience
#   - What: limited diesel backup only if renewables+storage cannot meet demand; negotiate fuel supply contracts with price hedges
#   - Timeline: Year 1–10
#   - Cost: $5–10M contingency and standby reserves
#   - Milestones: fuel-on-hand policy; defined trigger for backup usage
#   - Risks/uncertainties: fuel price spikes; mitigation by prioritizing energy resilience
#
# 3) Food security and nutrition: protein and staple supply
# - Action F1. Aquaponics greenhouses and selected high-protein crops
#   - What: build 1–2 compact aquaponics facilities; grow fish (e.g., tilapia) and leafy veggies; optimize water reuse
#   - Timeline: Year 2–4
#   - Cost: $8–12M
#   - Milestones: first harvest Year 3; target protein contribution increased by 5–15% of dietary protein by Year 5
#   - Benefits: local protein, reduced import bill, year-round production
#   - Risks/uncertainties: technology uptake, fish disease; mitigation with training and biosecurity plans
#
# - Action F2. Small-scale, low-footprint animal protein/alternative proteins
#   - What: pilot programs (insect protein, poultry, or other adaptable options) where feasible
#   - Timeline: Year 3–5
#   - Cost: $2–5M
#   - Milestones: pilot success; upscaling if feasible
#   - Risks: market acceptance; mitigation with community engagement
#
# - Action F3. Fisheries productivity and post-harvest improvements
#   - What: promote sustainable fishing practices, reduce post-harvest losses, cold-chain improvements for local markets
#   - Timeline: Year 1–5
#   - Cost: $3–5M
#   - Milestones: reduced spoilage; stable protein supply at community level
#   - Risks: enforcement challenges; mitigation with training and community-led governance
#
# 4) Governance, risk monitoring, and social equity
# - Action G1. Independent governance and participatory planning
#   - What: citizen assemblies, independent watchdog, transparent budgeting, open data
#   - Timeline: Year 1–10 (ongoing)
#   - Cost: $3–6M
#   - Milestones: annual public dashboards; independent audit each year
#   - Risks/mitigations: risk of capture; mitigate with rotating mandates and clear conflict-of-interest rules
#
# - Action G2. Early warning, climate risk monitoring, and adaptation feedback loops
#   - What: hazard warning system (storm surge, salt intrusion, drought), community alert networks
#   - Timeline: Year 1–3, ongoing
#   - Cost: $2–4M
#   - Milestones: functioning alerts; 24–48h notification windows for residents
#   - Risks: alert fatigue; mitigate with targeted segments and clear action guidelines
#
# - Action G3. Workforce training and local enterprise
#   - What: training programs for operation, maintenance, and local procurement; foster local service capacity
#   - Timeline: Year 1–10, ongoing
#   - Cost: $2–5M
#   - Milestones: local capacity indicators; increase in local maintenance jobs
#
# Cross-cutting contingency fund
# - Contingency fund: reserve 10–15% of total plan cost to cover overruns, price shocks, or faster-than-expected climate impacts.
#
# Overall timing and sequencing
# - Years 1–2: establish governance, data baseline, implement W1 (demand management), start W2 modular desalination pilots, begin E2/ E3 efficiency measures, begin F1 aquaponics pilot, start G1 governance and risk monitoring.
# - Years 3–5: scale W2 units if needed; expand W3 rainwater capture; deploy most of E1 solar+storage; broaden F1; advance G2 and G3; introduce F2/Pilot as feasible.
# - Years 6–10: stabilize W1/W2/W3; broaden E1/E2 to meet full demand; complete W4 recharge; scale up F1-3; ensure robust governance and transparent evaluation.
#
# Three alternative strategies if key assumptions change
# - Alternative A (groundwater decline slower than expected): de-emphasize large aquifer recharge timing; reallocate some W2 capacity to additional rainwater harvesting, efficiency, and river management; defer some desalination expansion until demand grows.
# - Alternative B (renewable energy generation or storage costs/availability higher than planned): prioritize aggressive energy efficiency (E2) and demand-side management; seek regional grid connections or borrow-to-invest for a staged, lower-capital renewables build; keep diesel backup as a last resort with hedging.
# - Alternative C (land and protein constraints tighten): accelerate aquaculture/prawn/seaweed options, intensify aquaponics, and expand fisheries value-chain investments; diversify protein supply beyond fish and crops; invest in protein-import efficiency (logistics and shelf life) while minimizing waste.
#
# (b) Quantitative estimates of costs, benefits, and risks (major actions)
#
# Note: all figures are rough, order-of-magnitude estimates, with ranges to reflect uncertainty. Probabilities are approximate and not guarantees.
#
# - W1. Demand management and leakage reduction
#   - Cost: $5–10M
#   - Benefits: 15–25% reduction in per-capita water use by Year 2; local water security improved; annual avoided groundwater pumping cost variable (depends on electricity and pumping cost)
#   - Risk/uncertainty: 0.2–0.4 risk of noncompliance, mitigated by community engagement
#   - Probability of achieving target: 0.6–0.8
#
# - W2. Desalination units + storage
#   - Cost: $40–65M (initial + expansion)
#   - Benefits: meets 40–80% of dry-season demand by Year 3; reduces salt intrusion risk; more reliable water supply
#   - Risk/uncertainty: 0.25–0.5
#   - Probability of achieving target: 0.6–0.8
#
# - W3. Rainwater harvesting and storage
#   - Cost: $5–12M
#   - Benefits: 10–20% of demand captured by Year 4; climate resilience
#   - Risk/uncertainty: 0.2–0.4
#   - Probability of achieving target: 0.6–0.7
#
# - W4. Groundwater management and recharge
#   - Cost: $20–30M
#   - Benefits: improved aquifer sustainability; salinity stabilization
#   - Risk/uncertainty: 0.3–0.5
#   - Probability of achieving target: 0.5–0.7
#
# - E1. Solar-wind microgrid with storage
#   - Cost: $30–90M (depending on scale and storage)
#   - Benefits: 24/7 pumping capability with high renewable share; lower fuel exposure
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - E2. Efficiency and demand management
#   - Cost: $5–10M
#   - Benefits: 15–30% reduction in pumping electricity by Year 2
#   - Risk/uncertainty: 0.2–0.3
#   - Probability of achieving target: 0.7–0.85
#
# - F1. Aquaponics greenhouse
#   - Cost: $8–12M
#   - Benefits: 5–15% of dietary protein by Year 5; year-round vegetable supply
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - F2/F3. Additional protein and fisheries improvements
#   - Cost: $5–8M
#   - Benefits: protein diversification; reduced waste
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.5–0.7
#
# - G1–G3. Governance, monitoring, training
#   - Cost: $5–10M total
#   - Benefits: higher plan fidelity; reduced governance risk
#   - Risk/uncertainty: 0.15–0.25
#   - Probability of achieving target: 0.75–0.9
#
# Contingency fund
# - 10–15% of total plan cost reserved for overruns, price spikes, or faster-than-expected climate impacts. This reduces the likelihood that a single shock derails the plan.
#
# Net impact expectations (illustrative)
# - Water security: major reduction in drought risk; more predictable water supply; groundwater decline mitigated when combined with W2–W4.
# - Energy: more reliable pumping for water and households; reduced fossil fuel exposure; gradual transition to renewables.
# - Food and nutrition: increased local protein and staples; reduced dietary risk if fishing catches fluctuate.
# - Social: improved public trust via transparency; better local job opportunities and skills development.
#
# (c) Assumptions and monitoring plan (how each assumption would be empirically tested)
#
# Key assumptions and tests
# - A1. Groundwater usable volume declines by 50% over 10 years due to saltwater intrusion/seawater intrusion.
#   - Test/monitor: quarterly groundwater salinity and level measurements at multiple wells; annual aquifer yield estimates; publish annual trend reports.
# - A2. River is seasonal but provides reliable wet-season supply.
#   - Test/monitor: river flow and seasonal discharge records; correlate with rainfall data; test with hydrological model updates annually.
# - A3. Renewable resources can reliably supply up to 15 MW (ratio of capacity factor to demand acceptable for pumping and household loads).
#   - Test/monitor: track solar/wind capacity factor, storage state-of-charge, and grid reliability; conduct quarterly reliability assessments.
# - A4. The budget remains fixed at $20M/year with no major fiscal shocks.
#   - Test/monitor: annual budget reviews; scenario analyses for cost overruns; publish quarterly expenditure reports.
# - A5. Fishing provides ~30% of dietary protein; aquaculture/alternate proteins will contribute meaningfully.
#   - Test/monitor: track dietary protein sources; monitor fish catch, aquaculture yields, and imports; adjust plans if reliance shifts.
# - A6. Land is limited but amenable to rainfed or controlled-environment agriculture.
#   - Test/monitor: land-use assessments; crop yields; soil and water quality tests for greenhouse operations.
# - A7. Local institutions can implement and maintain new systems with training.
#   - Test/monitor: track maintenance logs, training take-up, and operator certifications; independent audits.
#
# Monitoring framework
# - Establish a 3-year baseline for water demand, groundwater quality, renewable generation, and protein supply.
# - Quarterly public dashboards and annual independent audit.
# - Use scenario planning with annual updates (best-case, base-case, worst-case).
# - Independent technical advisor panel with rotating membership and conflict-of-interest safeguards.
# - Public engagement sessions after major milestones; adjust plan in response to feedback.
#
# (d) Cognitive biases, institutional failure modes, or socio-political obstacles and mitigation
#
# Biases and plan fragility
# - Optimism bias (overestimating benefits, underestimating costs)
#   - Mitigation: require independent external reviews; set “stop gates” at key milestones to reassess before scale-up.
# - Planning fallacy and sunk cost (continuing projects despite evidence of poor performance)
#   - Mitigation: implement mandatory mid-course corrections; predefine exit or pivot criteria; keep a scalable option inventory.
# - Anchoring to historical water/energy costs and patterns
#   - Mitigation: use multiple scenario analyses (low/high demand, climate extremes); revisit assumptions annually.
# - Availability heuristic (relying on recent events)
#   - Mitigation: formal risk register with probabilistic risk estimates; stress tests for extreme months/seasons.
# - Overconfidence in technology performance
#   - Mitigation: pilot testing, staged deployments, strict reliability targets, and contingency storage/backups.
# - Equity and social justice blind spots
#   - Mitigation: inclusive planning; targeted outreach to low-income households; ensure affordable access to water, energy, and food.
#
# Institutional and socio-political obstacles
# - Interagency coordination failures or siloed authorities
#   - Mitigation: a formal cross-agency steering committee with clear decision rights; shared data platforms.
# - Political economy capture by powerful groups (fisheries, landowners)
#   - Mitigation: independent oversight, transparent procurement, community representation, and performance-based funding.
# - Public trust and engagement gaps
#   - Mitigation: early and ongoing transparent communications; public dashboards; participatory budgeting options.
# - Funding volatility and macroeconomic shocks
#   - Mitigation: contingency fund; staged financing; explore external grants and concessional loans with clear milestones.
# - Workforce and capability gaps
#   - Mitigation: robust training, apprenticeships, and local job guarantees; partner with regional centers of excellence.
#
# (e) Public communication: concise 100-word summary (for skeptical residents)
#
# Text (exact 100 words)
# To protect water, food, and energy for our 10,000 residents over the next decade, we will invest in a diversified, reef-to-ridge resilience plan. We will reduce dependence on groundwater by expanding renewable-powered desalination, rainwater capture, and efficient water use; we will secure affordable, reliable electricity with a solar-wind microgrid and storage; we will boost local food by supporting aquaponics and fisheries improvements; we will strengthen governance, warning systems, and jobs through training and shared decision making. The plan uses our $20M/year budget, with transparent milestones and contingencies if conditions change. It aims fairness, jobs, and a safer island future together.
#
# (f) Transparent explanation of chain-of-reasoning and uncertainty points
#
# Chain-of-reasoning (high level)
# - Step 1: Define the system boundaries (water-energy-food nexus) and list constraints (10k people, $20M/year, 15 MW renewables potential, limited arable land, 30% protein from fishing).
# - Step 2: Identify the central risk drivers: groundwater decline, seasonal river reliability, energy reliability, protein supply, and governance capacity.
# - Step 3: Develop a portfolio of actions targeting water reliability, energy resilience, food security, and governance, each with milestones, costs, and risk controls.
# - Step 4: Prioritize actions by payoffs (water reliability and energy security for the population; strong governance to steer execution) and by feasibility under budget.
# - Step 5: Build contingencies for key assumption changes (groundwater decline rate; renewables costs; protein supply dynamics).
# - Step 6: Establish monitoring, independent oversight, and adaptive management so the plan can be revised in light of data.
#
# Uncertainty points and where the plan is likely to misestimate
# - Rate of groundwater decline (A1) and groundwater management effectiveness
#   - Risk: too-optimistic persistence of aquifer; plan must adjust W2/W3 emphasis if salinity or yield changes
# - Costs and performance of desalination and storage (W2)
#   - Risk: unit costs, energy needs, and maintenance could be higher; contingency and staged expansion help
# - Renewable energy performance and storage costs (E1)
#   - Risk: actual capacity factor and storage costs may diverge; plan relies on milestoned pilots and upgrades
# - Protein supply dynamics (F1–F3)
#   - Risk: aquaponics uptake, disease, or market acceptance could lag; alternative proteins and fisheries improvements provide backup
# - Governance and social acceptance
#   - Risk: delays in adoption, public distrust; mitigations include transparent dashboards and participatory processes
#
# If any of these uncertainties become dominant, the plan includes three alternative strategy packages (A, B, C) as described in section (a).
#
# Why this plan, and why now
# - It directly addresses the nexus of water, energy, and food with a diversified, modular, and costed approach that reduces risk exposure to any single resource or shock.
# - It uses the fixed annual budget to build resilience progressively, with milestones and independent oversight to maintain trust.
# - It anticipates potential changes in climate, technology, and social dynamics through explicit contingencies and alternative pathways.
#
# Notes for implementation
# - Start with a robust data baseline: water use, groundwater quality and levels, river flows, renewable resource assessments, and protein supply patterns.
# - Establish an independent monitoring and governance unit early, with transparent reporting.
# - Engage communities continuously to align priorities, distribute benefits, and maintain legitimacy.
#
# If you’d like, I can tailor the cost estimates to your island’s actual unit costs (labor, materials, fuel, maintenance), or draft a one-page dashboard (metrics, targets, and timelines) for council review.
# Competitor: gemma3:4b
#
# Okay, this is a complex challenge – a classic climate adaptation scenario demanding a nuanced and robust response. Here's my advisory plan, integrating the requested components, acknowledging uncertainties and incorporating a pragmatic, phased approach.
#
# **(a) Prioritized, Costed 10-Year Adaptation Plan**
#
# **Phase 1 (Years 1-3): Stabilization & Data Gathering ($6M)**
# * **Milestone 1:** Comprehensive Hydrogeological Survey - ($500k, 12 months) - Detailed mapping of aquifer recharge rates, salinity intrusion levels, and remaining groundwater potential.  Probability of success: 90% (based on existing data), risk mitigation: secondary surveys.
# * **Milestone 2:** River Water Management System Upgrade – ($1M, 18 months) – Repairing erosion control, improved diversion/storage, and water quality monitoring.
# * **Milestone 3:** Initial Solar/Wind Integration – ($2.5M, 24 months) – Installation of 5 MW solar/wind to power initial water purification.
#
# **Phase 2 (Years 4-7): Diversification & Resilience ($10M)**
# * **Milestone 4:**  Desalination Plant (1 MW) – ($4M, 36 months) – Initial pilot testing, expanded capacity based on water demand.  Contingency: If desalination proves too expensive, focus shifts to rainwater harvesting.
# * **Milestone 5:** Crop Diversification & Aquaponic Systems - ($2M, 36 months) – Implementing drought-resistant crops, establishing small-scale aquaponic farms.
# * **Milestone 6:**  Community Water Storage & Distribution ($2M, 36 months) – Building elevated storage tanks, improving distribution networks using renewable energy.
#
# **Phase 3 (Years 8-10): Long-Term Security & Adaptive Management ($4M)**
# * **Milestone 7:**  Second Desalination Plant (2 MW) – ($2.5M, 48 months) –Scaling up desal as saltwater intrusion worsens.
# * **Milestone 8:**  Climate Modelling & Research ($1M, 60 months) – Ongoing monitoring, research into alternative water sources & adaptation techniques.
#
#
#
# **(b) Quantitative Estimates (Ranges & Probabilities)**
#
# | Action                   | Cost (USD)   | Benefit (Water Availability - m3/year) | Risk (Probability, % ) | Benefit Probability |
# |---------------------------|---------------|---------------------------------------|-----------------------|-----------------------|
# | Hydrogeological Survey    | $500k          | N/A                                  | 10                      | 90%                    |
# | River Upgrade             | $1M           | 200,000                             | 20                     | 70%                    |
# | Solar/Wind Integration     | $2.5M         | N/A                                  | 5                      | 85%                    |
# | Desalination (1MW)        | $4M           | 1,500,000                             | 30                     | 60%                    |
# | Desalination (2MW)        | $2.5M         | 4,500,000                             | 40                     | 50%                    |
# | Crop Diversification       | $2M           | 50,000                               | 40                     | 75%                    |
# | Water Storage & Distribution| $2M           | 100,000                             | 25                     | 80%                    |
# | Climate Research          | $1M           | N/A                                  | 15                      | 95%                    |
#
# **(c) Assumptions & Monitoring**
#
# * **Sea-Level Rise:** Assumed to be 0.5m rise over 10 years (based on IPCC projections).  *Testing:* Monthly sea-level monitoring with tide gauges.
# * **Groundwater Recharge:**  Recharge rates are moderately stable. *Testing:* Continuous aquifer monitoring – water levels, salinity, and flow rates.
# * **Solar/Wind Output:**  Consistent renewable energy generation. *Testing:* Real-time monitoring of generation, with backup generator ready.
#
#
# **(d) Cognitive Biases & Mitigation**
#
# * **Confirmation Bias:** Prioritizing data supporting the desalination plan.  *Mitigation:* Structured, multidisciplinary assessment panel.
# * **Status Quo Bias:** Resistance to change and new technologies. *Mitigation:* Extensive community engagement, demonstration projects.
# * **Bandwagon Effect:**  Everyone rushes to invest in desalination; leads to inflated costs. *Mitigation:*  Procurement process with transparent bidding, independent expert reviews.
#
# **(e) Public Summary (100 Words)**
#
# "Our island faces a serious challenge: rising seas threaten our freshwater. This plan isn't just about surviving; it’s about securing our future. We’ll combine smarter water management with sustainable solutions like solar and aquaponics.  This initial $20M investment, built from a mix of funds, isn’t a cost but an insurance policy for our community’s health, food security, and prosperity using proven technologies, ensuring our island thrives for generations to come."
#
# **(f) Chain of Reasoning & Uncertainties**
#
# I'm heavily reliant on the sea-level rise prediction (0.5m), which has vast uncertainty.  My primary analysis assumes a relatively stable groundwater recharge rate, which could be significantly affected by climate-induced changes to rainfall patterns. The success of solar/wind integration hinges on consistent resource availability—a risk addressed with battery storage. My confidence in desalination’s affordability and long-term operation is moderate, based on the relatively untested technology – therefore, phased investment is key. The biggest risk is a "black swan" event – a significantly accelerated sea-level rise or a catastrophic failure of core infrastructure.
#
#
#
# Do you want me to elaborate on any particular aspect, refine the plan, or assess a specific risk in more detail?  Let me know how I can help you further!

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Here is a structured, action-focused plan you can adapt for the council. I’ve bundled it to fit the island’s water-energy-food nexus, budget, and social context, with clear milestones, contingencies, and risk management.
#
# (a) Prioritized, costed 10-year adaptation plan (milestones, contingencies, and three alternative strategies)
#
# Strategic pillars
# - Water security and resilience (reduce groundwater vulnerability; diversify supply)
# - Energy resilience (renewables-based microgrid; reliable pumping and storage)
# - Food security and nutrition (increase local protein and staples; reduce import risk)
# - Infrastructure, governance, and risk monitoring (trusted, transparent, adaptive)
#
# Year-by-year actions (highlights; budget: total ≈ $150–190M over 10 years; annual capex ≈ $20M, plus a contingency fund)
#
# 1) Water security: demand, supply, and protection
# - Action W1. Water demand management and leakage reduction
#   - What: audit current use, fix leaks, fix inefficient fixtures, public water-use campaign; pricing signals optional but transparent.
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: baseline water use; 15–25% reduction in per-capita use by Year 2; 10–15% reduction in non-revenue water
#   - Contingencies: if savings underperform, escalate with stricter water-use rules and incentives
#   - Risks/uncertainties: public opposition to restrictions; mitigation with inclusive planning and compensation for hardship
#
# - Action W2. Desalination and/or seawater intrusion barriers (modular approach)
#   - What: deploy 1–2 small modular desalination units (target 1.5–2.5 million L/day) powered by solar/wind; consider brine management; staged expansion to meet demand if groundwater declines faster.
#   - Timeline: Year 1–3 initial units; Year 4–5 scale-up if needed
#   - Cost: $40–65M (including energy integration and storage interfaces)
#   - Milestones: unit commissioning; supply meets 40–60% of peak demand in dry season by Year 3; expansion to 70–80% by Year 5 if groundwater declines faster
#   - Contingencies: if desalination costs or operations are higher-than-expected, rely more on rainwater harvesting and river recharge
#   - Risks/uncertainties: energy supply reliability; brine disposal impacts; mitigation with robust monitoring and guaranteed maintenance contracts
#
# - Action W3. Rainwater harvesting and storage improvements
#   - What: retrofit roofs/municipal facilities; build above-ground storage and infiltration basins; treat and reuse graywater where feasible
#   - Timeline: Year 1–4
#   - Cost: $5–12M
#   - Milestones: capture capacity added to 10–20% of demand by Year 4
#   - Contingencies: if rainfall is less than expected, prioritize urban harvesting and in-building storage
#   - Risks/uncertainties: climate variability; mitigation with diversified sources
#
# - Action W4. Groundwater protection and managed aquifer recharge (if aquifer present)
#   - What: monitor salinity and levels; create recharge basins using treated water or captured rain; regulate abstraction to sustainable yield
#   - Timeline: Year 1–Year 6 (steady progress)
#   - Cost: $20–30M
#   - Milestones: establish baseline salinity/levels; implement managed yield target; regular reporting
#   - Contingencies: scale-back if aquifer proves less viable; reallocate to W1–W3
#   - Risks/uncertainties: effectiveness of recharge; governance of water rights
#
# - Action W5. Water monitoring, quality, and governance
#   - What: install continuous water-quality sensors; create data dashboards; public annual reports; independent technical oversight
#   - Timeline: Year 1–Year 2 (setup); ongoing
#   - Cost: $3–6M
#   - Milestones: real-time data feeds; quarterly performance reviews
#   - Risks/uncertainties: data reliability; mitigation with redundancy and third-party QA
#
# 2) Energy resilience: renewables, storage, and reliable pumping
# - Action E1. Solar-wwind microgrid with storage (staged)
#   - What: install 5–7 MW initial renewable capacity; add storage to balance pumping and peak demand; create island-wide microgrid with islanded operation capability
#   - Timeline: Year 1–3 (initial); Year 4–6 expansion
#   - Cost: $30–60M (initial; total may reach $60–90M with storage expansion)
#   - Milestones: 24/7 pumping reliability for water system in dry season by Year 3; >80% daytime energy from renewables; storage sufficiency during outages
#   - Contingencies: if capital costs or maintenance rise, defer some capacity and use more targeted battery storage; otherwise add diesel-free back-up
#   - Risks/uncertainties: resource variability; storage cost and lifecycle; mitigation with modular installs and long-term O&M contracts
#
# - Action E2. Energy efficiency and demand-side management for pumps and public buildings
#   - What: high-efficiency pumps, VFDs, smart controls; seasonally adjusted pumping schedules
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: pump efficiency improvements; energy-use reductions of 15–30% in water pumping by Year 2
#   - Risks/uncertainties: device performance; mitigation with manufacturer warranties and local training
#
# - Action E3. Contingent backup planning and fuel resilience
#   - What: limited diesel backup only if renewables+storage cannot meet demand; negotiate fuel supply contracts with price hedges
#   - Timeline: Year 1–10
#   - Cost: $5–10M contingency and standby reserves
#   - Milestones: fuel-on-hand policy; defined trigger for backup usage
#   - Risks/uncertainties: fuel price spikes; mitigation by prioritizing energy resilience
#
# 3) Food security and nutrition: protein and staple supply
# - Action F1. Aquaponics greenhouses and selected high-protein crops
#   - What: build 1–2 compact aquaponics facilities; grow fish (e.g., tilapia) and leafy veggies; optimize water reuse
#   - Timeline: Year 2–4
#   - Cost: $8–12M
#   - Milestones: first harvest Year 3; target protein contribution increased by 5–15% of dietary protein by Year 5
#   - Benefits: local protein, reduced import bill, year-round production
#   - Risks/uncertainties: technology uptake, fish disease; mitigation with training and biosecurity plans
#
# - Action F2. Small-scale, low-footprint animal protein/alternative proteins
#   - What: pilot programs (insect protein, poultry, or other adaptable options) where feasible
#   - Timeline: Year 3–5
#   - Cost: $2–5M
#   - Milestones: pilot success; upscaling if feasible
#   - Risks: market acceptance; mitigation with community engagement
#
# - Action F3. Fisheries productivity and post-harvest improvements
#   - What: promote sustainable fishing practices, reduce post-harvest losses, cold-chain improvements for local markets
#   - Timeline: Year 1–5
#   - Cost: $3–5M
#   - Milestones: reduced spoilage; stable protein supply at community level
#   - Risks: enforcement challenges; mitigation with training and community-led governance
#
# 4) Governance, risk monitoring, and social equity
# - Action G1. Independent governance and participatory planning
#   - What: citizen assemblies, independent watchdog, transparent budgeting, open data
#   - Timeline: Year 1–10 (ongoing)
#   - Cost: $3–6M
#   - Milestones: annual public dashboards; independent audit each year
#   - Risks/mitigations: risk of capture; mitigate with rotating mandates and clear conflict-of-interest rules
#
# - Action G2. Early warning, climate risk monitoring, and adaptation feedback loops
#   - What: hazard warning system (storm surge, salt intrusion, drought), community alert networks
#   - Timeline: Year 1–3, ongoing
#   - Cost: $2–4M
#   - Milestones: functioning alerts; 24–48h notification windows for residents
#   - Risks: alert fatigue; mitigate with targeted segments and clear action guidelines
#
# - Action G3. Workforce training and local enterprise
#   - What: training programs for operation, maintenance, and local procurement; foster local service capacity
#   - Timeline: Year 1–10, ongoing
#   - Cost: $2–5M
#   - Milestones: local capacity indicators; increase in local maintenance jobs
#
# Cross-cutting contingency fund
# - Contingency fund: reserve 10–15% of total plan cost to cover overruns, price shocks, or faster-than-expected climate impacts.
#
# Overall timing and sequencing
# - Years 1–2: establish governance, data baseline, implement W1 (demand management), start W2 modular desalination pilots, begin E2/ E3 efficiency measures, begin F1 aquaponics pilot, start G1 governance and risk monitoring.
# - Years 3–5: scale W2 units if needed; expand W3 rainwater capture; deploy most of E1 solar+storage; broaden F1; advance G2 and G3; introduce F2/Pilot as feasible.
# - Years 6–10: stabilize W1/W2/W3; broaden E1/E2 to meet full demand; complete W4 recharge; scale up F1-3; ensure robust governance and transparent evaluation.
#
# Three alternative strategies if key assumptions change
# - Alternative A (groundwater decline slower than expected): de-emphasize large aquifer recharge timing; reallocate some W2 capacity to additional rainwater harvesting, efficiency, and river management; defer some desalination expansion until demand grows.
# - Alternative B (renewable energy generation or storage costs/availability higher than planned): prioritize aggressive energy efficiency (E2) and demand-side management; seek regional grid connections or borrow-to-invest for a staged, lower-capital renewables build; keep diesel backup as a last resort with hedging.
# - Alternative C (land and protein constraints tighten): accelerate aquaculture/prawn/seaweed options, intensify aquaponics, and expand fisheries value-chain investments; diversify protein supply beyond fish and crops; invest in protein-import efficiency (logistics and shelf life) while minimizing waste.
#
# (b) Quantitative estimates of costs, benefits, and risks (major actions)
#
# Note: all figures are rough, order-of-magnitude estimates, with ranges to reflect uncertainty. Probabilities are approximate and not guarantees.
#
# - W1. Demand management and leakage reduction
#   - Cost: $5–10M
#   - Benefits: 15–25% reduction in per-capita water use by Year 2; local water security improved; annual avoided groundwater pumping cost variable (depends on electricity and pumping cost)
#   - Risk/uncertainty: 0.2–0.4 risk of noncompliance, mitigated by community engagement
#   - Probability of achieving target: 0.6–0.8
#
# - W2. Desalination units + storage
#   - Cost: $40–65M (initial + expansion)
#   - Benefits: meets 40–80% of dry-season demand by Year 3; reduces salt intrusion risk; more reliable water supply
#   - Risk/uncertainty: 0.25–0.5
#   - Probability of achieving target: 0.6–0.8
#
# - W3. Rainwater harvesting and storage
#   - Cost: $5–12M
#   - Benefits: 10–20% of demand captured by Year 4; climate resilience
#   - Risk/uncertainty: 0.2–0.4
#   - Probability of achieving target: 0.6–0.7
#
# - W4. Groundwater management and recharge
#   - Cost: $20–30M
#   - Benefits: improved aquifer sustainability; salinity stabilization
#   - Risk/uncertainty: 0.3–0.5
#   - Probability of achieving target: 0.5–0.7
#
# - E1. Solar-wind microgrid with storage
#   - Cost: $30–90M (depending on scale and storage)
#   - Benefits: 24/7 pumping capability with high renewable share; lower fuel exposure
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - E2. Efficiency and demand management
#   - Cost: $5–10M
#   - Benefits: 15–30% reduction in pumping electricity by Year 2
#   - Risk/uncertainty: 0.2–0.3
#   - Probability of achieving target: 0.7–0.85
#
# - F1. Aquaponics greenhouse
#   - Cost: $8–12M
#   - Benefits: 5–15% of dietary protein by Year 5; year-round vegetable supply
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - F2/F3. Additional protein and fisheries improvements
#   - Cost: $5–8M
#   - Benefits: protein diversification; reduced waste
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.5–0.7
#
# - G1–G3. Governance, monitoring, training
#   - Cost: $5–10M total
#   - Benefits: higher plan fidelity; reduced governance risk
#   - Risk/uncertainty: 0.15–0.25
#   - Probability of achieving target: 0.75–0.9
#
# Contingency fund
# - 10–15% of total plan cost reserved for overruns, price spikes, or faster-than-expected climate impacts. This reduces the likelihood that a single shock derails the plan.
#
# Net impact expectations (illustrative)
# - Water security: major reduction in drought risk; more predictable water supply; groundwater decline mitigated when combined with W2–W4.
# - Energy: more reliable pumping for water and households; reduced fossil fuel exposure; gradual transition to renewables.
# - Food and nutrition: increased local protein and staples; reduced dietary risk if fishing catches fluctuate.
# - Social: improved public trust via transparency; better local job opportunities and skills development.
#
# (c) Assumptions and monitoring plan (how each assumption would be empirically tested)
#
# Key assumptions and tests
# - A1. Groundwater usable volume declines by 50% over 10 years due to saltwater intrusion/seawater intrusion.
#   - Test/monitor: quarterly groundwater salinity and level measurements at multiple wells; annual aquifer yield estimates; publish annual trend reports.
# - A2. River is seasonal but provides reliable wet-season supply.
#   - Test/monitor: river flow and seasonal discharge records; correlate with rainfall data; test with hydrological model updates annually.
# - A3. Renewable resources can reliably supply up to 15 MW (ratio of capacity factor to demand acceptable for pumping and household loads).
#   - Test/monitor: track solar/wind capacity factor, storage state-of-charge, and grid reliability; conduct quarterly reliability assessments.
# - A4. The budget remains fixed at $20M/year with no major fiscal shocks.
#   - Test/monitor: annual budget reviews; scenario analyses for cost overruns; publish quarterly expenditure reports.
# - A5. Fishing provides ~30% of dietary protein; aquaculture/alternate proteins will contribute meaningfully.
#   - Test/monitor: track dietary protein sources; monitor fish catch, aquaculture yields, and imports; adjust plans if reliance shifts.
# - A6. Land is limited but amenable to rainfed or controlled-environment agriculture.
#   - Test/monitor: land-use assessments; crop yields; soil and water quality tests for greenhouse operations.
# - A7. Local institutions can implement and maintain new systems with training.
#   - Test/monitor: track maintenance logs, training take-up, and operator certifications; independent audits.
#
# Monitoring framework
# - Establish a 3-year baseline for water demand, groundwater quality, renewable generation, and protein supply.
# - Quarterly public dashboards and annual independent audit.
# - Use scenario planning with annual updates (best-case, base-case, worst-case).
# - Independent technical advisor panel with rotating membership and conflict-of-interest safeguards.
# - Public engagement sessions after major milestones; adjust plan in response to feedback.
#
# (d) Cognitive biases, institutional failure modes, or socio-political obstacles and mitigation
#
# Biases and plan fragility
# - Optimism bias (overestimating benefits, underestimating costs)
#   - Mitigation: require independent external reviews; set “stop gates” at key milestones to reassess before scale-up.
# - Planning fallacy and sunk cost (continuing projects despite evidence of poor performance)
#   - Mitigation: implement mandatory mid-course corrections; predefine exit or pivot criteria; keep a scalable option inventory.
# - Anchoring to historical water/energy costs and patterns
#   - Mitigation: use multiple scenario analyses (low/high demand, climate extremes); revisit assumptions annually.
# - Availability heuristic (relying on recent events)
#   - Mitigation: formal risk register with probabilistic risk estimates; stress tests for extreme months/seasons.
# - Overconfidence in technology performance
#   - Mitigation: pilot testing, staged deployments, strict reliability targets, and contingency storage/backups.
# - Equity and social justice blind spots
#   - Mitigation: inclusive planning; targeted outreach to low-income households; ensure affordable access to water, energy, and food.
#
# Institutional and socio-political obstacles
# - Interagency coordination failures or siloed authorities
#   - Mitigation: a formal cross-agency steering committee with clear decision rights; shared data platforms.
# - Political economy capture by powerful groups (fisheries, landowners)
#   - Mitigation: independent oversight, transparent procurement, community representation, and performance-based funding.
# - Public trust and engagement gaps
#   - Mitigation: early and ongoing transparent communications; public dashboards; participatory budgeting options.
# - Funding volatility and macroeconomic shocks
#   - Mitigation: contingency fund; staged financing; explore external grants and concessional loans with clear milestones.
# - Workforce and capability gaps
#   - Mitigation: robust training, apprenticeships, and local job guarantees; partner with regional centers of excellence.
#
# (e) Public communication: concise 100-word summary (for skeptical residents)
#
# Text (exact 100 words)
# To protect water, food, and energy for our 10,000 residents over the next decade, we will invest in a diversified, reef-to-ridge resilience plan. We will reduce dependence on groundwater by expanding renewable-powered desalination, rainwater capture, and efficient water use; we will secure affordable, reliable electricity with a solar-wind microgrid and storage; we will boost local food by supporting aquaponics and fisheries improvements; we will strengthen governance, warning systems, and jobs through training and shared decision making. The plan uses our $20M/year budget, with transparent milestones and contingencies if conditions change. It aims fairness, jobs, and a safer island future together.
#
# (f) Transparent explanation of chain-of-reasoning and uncertainty points
#
# Chain-of-reasoning (high level)
# - Step 1: Define the system boundaries (water-energy-food nexus) and list constraints (10k people, $20M/year, 15 MW renewables potential, limited arable land, 30% protein from fishing).
# - Step 2: Identify the central risk drivers: groundwater decline, seasonal river reliability, energy reliability, protein supply, and governance capacity.
# - Step 3: Develop a portfolio of actions targeting water reliability, energy resilience, food security, and governance, each with milestones, costs, and risk controls.
# - Step 4: Prioritize actions by payoffs (water reliability and energy security for the population; strong governance to steer execution) and by feasibility under budget.
# - Step 5: Build contingencies for key assumption changes (groundwater decline rate; renewables costs; protein supply dynamics).
# - Step 6: Establish monitoring, independent oversight, and adaptive management so the plan can be revised in light of data.
#
# Uncertainty points and where the plan is likely to misestimate
# - Rate of groundwater decline (A1) and groundwater management effectiveness
#   - Risk: too-optimistic persistence of aquifer; plan must adjust W2/W3 emphasis if salinity or yield changes
# - Costs and performance of desalination and storage (W2)
#   - Risk: unit costs, energy needs, and maintenance could be higher; contingency and staged expansion help
# - Renewable energy performance and storage costs (E1)
#   - Risk: actual capacity factor and storage costs may diverge; plan relies on milestoned pilots and upgrades
# - Protein supply dynamics (F1–F3)
#   - Risk: aquaponics uptake, disease, or market acceptance could lag; alternative proteins and fisheries improvements provide backup
# - Governance and social acceptance
#   - Risk: delays in adoption, public distrust; mitigations include transparent dashboards and participatory processes
#
# If any of these uncertainties become dominant, the plan includes three alternative strategy packages (A, B, C) as described in section (a).
#
# Why this plan, and why now
# - It directly addresses the nexus of water, energy, and food with a diversified, modular, and costed approach that reduces risk exposure to any single resource or shock.
# - It uses the fixed annual budget to build resilience progressively, with milestones and independent oversight to maintain trust.
# - It anticipates potential changes in climate, technology, and social dynamics through explicit contingencies and alternative pathways.
#
# Notes for implementation
# - Start with a robust data baseline: water use, groundwater quality and levels, river flows, renewable resource assessments, and protein supply patterns.
# - Establish an independent monitoring and governance unit early, with transparent reporting.
# - Engage communities continuously to align priorities, distribute benefits, and maintain legitimacy.
#
# If you’d like, I can tailor the cost estimates to your island’s actual unit costs (labor, materials, fuel, maintenance), or draft a one-page dashboard (metrics, targets, and timelines) for council review.
#
# # Response from competitor 2
#
# Okay, this is a complex challenge – a classic climate adaptation scenario demanding a nuanced and robust response. Here's my advisory plan, integrating the requested components, acknowledging uncertainties and incorporating a pragmatic, phased approach.
#
# **(a) Prioritized, Costed 10-Year Adaptation Plan**
#
# **Phase 1 (Years 1-3): Stabilization & Data Gathering ($6M)**
# * **Milestone 1:** Comprehensive Hydrogeological Survey - ($500k, 12 months) - Detailed mapping of aquifer recharge rates, salinity intrusion levels, and remaining groundwater potential.  Probability of success: 90% (based on existing data), risk mitigation: secondary surveys.
# * **Milestone 2:** River Water Management System Upgrade – ($1M, 18 months) – Repairing erosion control, improved diversion/storage, and water quality monitoring.
# * **Milestone 3:** Initial Solar/Wind Integration – ($2.5M, 24 months) – Installation of 5 MW solar/wind to power initial water purification.
#
# **Phase 2 (Years 4-7): Diversification & Resilience ($10M)**
# * **Milestone 4:**  Desalination Plant (1 MW) – ($4M, 36 months) – Initial pilot testing, expanded capacity based on water demand.  Contingency: If desalination proves too expensive, focus shifts to rainwater harvesting.
# * **Milestone 5:** Crop Diversification & Aquaponic Systems - ($2M, 36 months) – Implementing drought-resistant crops, establishing small-scale aquaponic farms.
# * **Milestone 6:**  Community Water Storage & Distribution ($2M, 36 months) – Building elevated storage tanks, improving distribution networks using renewable energy.
#
# **Phase 3 (Years 8-10): Long-Term Security & Adaptive Management ($4M)**
# * **Milestone 7:**  Second Desalination Plant (2 MW) – ($2.5M, 48 months) –Scaling up desal as saltwater intrusion worsens.
# * **Milestone 8:**  Climate Modelling & Research ($1M, 60 months) – Ongoing monitoring, research into alternative water sources & adaptation techniques.
#
#
#
# **(b) Quantitative Estimates (Ranges & Probabilities)**
#
# | Action                   | Cost (USD)   | Benefit (Water Availability - m3/year) | Risk (Probability, % ) | Benefit Probability |
# |---------------------------|---------------|---------------------------------------|-----------------------|-----------------------|
# | Hydrogeological Survey    | $500k          | N/A                                  | 10                      | 90%                    |
# | River Upgrade             | $1M           | 200,000                             | 20                     | 70%                    |
# | Solar/Wind Integration     | $2.5M         | N/A                                  | 5                      | 85%                    |
# | Desalination (1MW)        | $4M           | 1,500,000                             | 30                     | 60%                    |
# | Desalination (2MW)        | $2.5M         | 4,500,000                             | 40                     | 50%                    |
# | Crop Diversification       | $2M           | 50,000                               | 40                     | 75%                    |
# | Water Storage & Distribution| $2M           | 100,000                             | 25                     | 80%                    |
# | Climate Research          | $1M           | N/A                                  | 15                      | 95%                    |
#
# **(c) Assumptions & Monitoring**
#
# * **Sea-Level Rise:** Assumed to be 0.5m rise over 10 years (based on IPCC projections).  *Testing:* Monthly sea-level monitoring with tide gauges.
# * **Groundwater Recharge:**  Recharge rates are moderately stable. *Testing:* Continuous aquifer monitoring – water levels, salinity, and flow rates.
# * **Solar/Wind Output:**  Consistent renewable energy generation. *Testing:* Real-time monitoring of generation, with backup generator ready.
#
#
# **(d) Cognitive Biases & Mitigation**
#
# * **Confirmation Bias:** Prioritizing data supporting the desalination plan.  *Mitigation:* Structured, multidisciplinary assessment panel.
# * **Status Quo Bias:** Resistance to change and new technologies. *Mitigation:* Extensive community engagement, demonstration projects.
# * **Bandwagon Effect:**  Everyone rushes to invest in desalination; leads to inflated costs. *Mitigation:*  Procurement process with transparent bidding, independent expert reviews.
#
# **(e) Public Summary (100 Words)**
#
# "Our island faces a serious challenge: rising seas threaten our freshwater. This plan isn't just about surviving; it’s about securing our future. We’ll combine smarter water management with sustainable solutions like solar and aquaponics.  This initial $20M investment, built from a mix of funds, isn’t a cost but an insurance policy for our community’s health, food security, and prosperity using proven technologies, ensuring our island thrives for generations to come."
#
# **(f) Chain of Reasoning & Uncertainties**
#
# I'm heavily reliant on the sea-level rise prediction (0.5m), which has vast uncertainty.  My primary analysis assumes a relatively stable groundwater recharge rate, which could be significantly affected by climate-induced changes to rainfall patterns. The success of solar/wind integration hinges on consistent resource availability—a risk addressed with battery storage. My confidence in desalination’s affordability and long-term operation is moderate, based on the relatively untested technology – therefore, phased investment is key. The biggest risk is a "black swan" event – a significantly accelerated sea-level rise or a catastrophic failure of core infrastructure.
#
#
#
# Do you want me to elaborate on any particular aspect, refine the plan, or assess a specific risk in more detail?  Let me know how I can help you further!

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# Imagine a remote island community of 10,000 people whose freshwater supply is currently 60% groundwater (abstraction wells) and 40% a seasonal river; sea-level rise and saltwater intrusion are projected to reduce usable groundwater by 50% over 10 years, the island has a fixed annual budget of $20M for infrastructure and social programs, access to solar and wind resources sufficient to generate up to 15 MW, limited arable land, and a fishing industry providing 30% of dietary protein—you're advising the community council: provide (a) a prioritized, costed 10-year adaptation plan with concrete milestones and clear contingencies, including at least three alternative strategies if key assumptions change; (b) quantitative estimates of costs, benefits, and risks (with ranges and approximate probabilities) for each major action; (c) an explicit list of assumptions and how each would be empirically tested or monitored; (d) identification of cognitive biases, institutional failure modes, or socio-political obstacles that could derail the plan and mitigation measures for each; (e) a concise 100-word public summary to persuade skeptical residents of the plan's necessity and fairness; and (f) a transparent explanation of the chain of reasoning you used, with explicit points where your analysis is uncertain or likely to be wrong—what do you propose and why?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Here is a structured, action-focused plan you can adapt for the council. I’ve bundled it to fit the island’s water-energy-food nexus, budget, and social context, with clear milestones, contingencies, and risk management.
#
# (a) Prioritized, costed 10-year adaptation plan (milestones, contingencies, and three alternative strategies)
#
# Strategic pillars
# - Water security and resilience (reduce groundwater vulnerability; diversify supply)
# - Energy resilience (renewables-based microgrid; reliable pumping and storage)
# - Food security and nutrition (increase local protein and staples; reduce import risk)
# - Infrastructure, governance, and risk monitoring (trusted, transparent, adaptive)
#
# Year-by-year actions (highlights; budget: total ≈ $150–190M over 10 years; annual capex ≈ $20M, plus a contingency fund)
#
# 1) Water security: demand, supply, and protection
# - Action W1. Water demand management and leakage reduction
#   - What: audit current use, fix leaks, fix inefficient fixtures, public water-use campaign; pricing signals optional but transparent.
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: baseline water use; 15–25% reduction in per-capita use by Year 2; 10–15% reduction in non-revenue water
#   - Contingencies: if savings underperform, escalate with stricter water-use rules and incentives
#   - Risks/uncertainties: public opposition to restrictions; mitigation with inclusive planning and compensation for hardship
#
# - Action W2. Desalination and/or seawater intrusion barriers (modular approach)
#   - What: deploy 1–2 small modular desalination units (target 1.5–2.5 million L/day) powered by solar/wind; consider brine management; staged expansion to meet demand if groundwater declines faster.
#   - Timeline: Year 1–3 initial units; Year 4–5 scale-up if needed
#   - Cost: $40–65M (including energy integration and storage interfaces)
#   - Milestones: unit commissioning; supply meets 40–60% of peak demand in dry season by Year 3; expansion to 70–80% by Year 5 if groundwater declines faster
#   - Contingencies: if desalination costs or operations are higher-than-expected, rely more on rainwater harvesting and river recharge
#   - Risks/uncertainties: energy supply reliability; brine disposal impacts; mitigation with robust monitoring and guaranteed maintenance contracts
#
# - Action W3. Rainwater harvesting and storage improvements
#   - What: retrofit roofs/municipal facilities; build above-ground storage and infiltration basins; treat and reuse graywater where feasible
#   - Timeline: Year 1–4
#   - Cost: $5–12M
#   - Milestones: capture capacity added to 10–20% of demand by Year 4
#   - Contingencies: if rainfall is less than expected, prioritize urban harvesting and in-building storage
#   - Risks/uncertainties: climate variability; mitigation with diversified sources
#
# - Action W4. Groundwater protection and managed aquifer recharge (if aquifer present)
#   - What: monitor salinity and levels; create recharge basins using treated water or captured rain; regulate abstraction to sustainable yield
#   - Timeline: Year 1–Year 6 (steady progress)
#   - Cost: $20–30M
#   - Milestones: establish baseline salinity/levels; implement managed yield target; regular reporting
#   - Contingencies: scale-back if aquifer proves less viable; reallocate to W1–W3
#   - Risks/uncertainties: effectiveness of recharge; governance of water rights
#
# - Action W5. Water monitoring, quality, and governance
#   - What: install continuous water-quality sensors; create data dashboards; public annual reports; independent technical oversight
#   - Timeline: Year 1–Year 2 (setup); ongoing
#   - Cost: $3–6M
#   - Milestones: real-time data feeds; quarterly performance reviews
#   - Risks/uncertainties: data reliability; mitigation with redundancy and third-party QA
#
# 2) Energy resilience: renewables, storage, and reliable pumping
# - Action E1. Solar-wwind microgrid with storage (staged)
#   - What: install 5–7 MW initial renewable capacity; add storage to balance pumping and peak demand; create island-wide microgrid with islanded operation capability
#   - Timeline: Year 1–3 (initial); Year 4–6 expansion
#   - Cost: $30–60M (initial; total may reach $60–90M with storage expansion)
#   - Milestones: 24/7 pumping reliability for water system in dry season by Year 3; >80% daytime energy from renewables; storage sufficiency during outages
#   - Contingencies: if capital costs or maintenance rise, defer some capacity and use more targeted battery storage; otherwise add diesel-free back-up
#   - Risks/uncertainties: resource variability; storage cost and lifecycle; mitigation with modular installs and long-term O&M contracts
#
# - Action E2. Energy efficiency and demand-side management for pumps and public buildings
#   - What: high-efficiency pumps, VFDs, smart controls; seasonally adjusted pumping schedules
#   - Timeline: Year 1–2
#   - Cost: $5–10M
#   - Milestones: pump efficiency improvements; energy-use reductions of 15–30% in water pumping by Year 2
#   - Risks/uncertainties: device performance; mitigation with manufacturer warranties and local training
#
# - Action E3. Contingent backup planning and fuel resilience
#   - What: limited diesel backup only if renewables+storage cannot meet demand; negotiate fuel supply contracts with price hedges
#   - Timeline: Year 1–10
#   - Cost: $5–10M contingency and standby reserves
#   - Milestones: fuel-on-hand policy; defined trigger for backup usage
#   - Risks/uncertainties: fuel price spikes; mitigation by prioritizing energy resilience
#
# 3) Food security and nutrition: protein and staple supply
# - Action F1. Aquaponics greenhouses and selected high-protein crops
#   - What: build 1–2 compact aquaponics facilities; grow fish (e.g., tilapia) and leafy veggies; optimize water reuse
#   - Timeline: Year 2–4
#   - Cost: $8–12M
#   - Milestones: first harvest Year 3; target protein contribution increased by 5–15% of dietary protein by Year 5
#   - Benefits: local protein, reduced import bill, year-round production
#   - Risks/uncertainties: technology uptake, fish disease; mitigation with training and biosecurity plans
#
# - Action F2. Small-scale, low-footprint animal protein/alternative proteins
#   - What: pilot programs (insect protein, poultry, or other adaptable options) where feasible
#   - Timeline: Year 3–5
#   - Cost: $2–5M
#   - Milestones: pilot success; upscaling if feasible
#   - Risks: market acceptance; mitigation with community engagement
#
# - Action F3. Fisheries productivity and post-harvest improvements
#   - What: promote sustainable fishing practices, reduce post-harvest losses, cold-chain improvements for local markets
#   - Timeline: Year 1–5
#   - Cost: $3–5M
#   - Milestones: reduced spoilage; stable protein supply at community level
#   - Risks: enforcement challenges; mitigation with training and community-led governance
#
# 4) Governance, risk monitoring, and social equity
# - Action G1. Independent governance and participatory planning
#   - What: citizen assemblies, independent watchdog, transparent budgeting, open data
#   - Timeline: Year 1–10 (ongoing)
#   - Cost: $3–6M
#   - Milestones: annual public dashboards; independent audit each year
#   - Risks/mitigations: risk of capture; mitigate with rotating mandates and clear conflict-of-interest rules
#
# - Action G2. Early warning, climate risk monitoring, and adaptation feedback loops
#   - What: hazard warning system (storm surge, salt intrusion, drought), community alert networks
#   - Timeline: Year 1–3, ongoing
#   - Cost: $2–4M
#   - Milestones: functioning alerts; 24–48h notification windows for residents
#   - Risks: alert fatigue; mitigate with targeted segments and clear action guidelines
#
# - Action G3. Workforce training and local enterprise
#   - What: training programs for operation, maintenance, and local procurement; foster local service capacity
#   - Timeline: Year 1–10, ongoing
#   - Cost: $2–5M
#   - Milestones: local capacity indicators; increase in local maintenance jobs
#
# Cross-cutting contingency fund
# - Contingency fund: reserve 10–15% of total plan cost to cover overruns, price shocks, or faster-than-expected climate impacts.
#
# Overall timing and sequencing
# - Years 1–2: establish governance, data baseline, implement W1 (demand management), start W2 modular desalination pilots, begin E2/ E3 efficiency measures, begin F1 aquaponics pilot, start G1 governance and risk monitoring.
# - Years 3–5: scale W2 units if needed; expand W3 rainwater capture; deploy most of E1 solar+storage; broaden F1; advance G2 and G3; introduce F2/Pilot as feasible.
# - Years 6–10: stabilize W1/W2/W3; broaden E1/E2 to meet full demand; complete W4 recharge; scale up F1-3; ensure robust governance and transparent evaluation.
#
# Three alternative strategies if key assumptions change
# - Alternative A (groundwater decline slower than expected): de-emphasize large aquifer recharge timing; reallocate some W2 capacity to additional rainwater harvesting, efficiency, and river management; defer some desalination expansion until demand grows.
# - Alternative B (renewable energy generation or storage costs/availability higher than planned): prioritize aggressive energy efficiency (E2) and demand-side management; seek regional grid connections or borrow-to-invest for a staged, lower-capital renewables build; keep diesel backup as a last resort with hedging.
# - Alternative C (land and protein constraints tighten): accelerate aquaculture/prawn/seaweed options, intensify aquaponics, and expand fisheries value-chain investments; diversify protein supply beyond fish and crops; invest in protein-import efficiency (logistics and shelf life) while minimizing waste.
#
# (b) Quantitative estimates of costs, benefits, and risks (major actions)
#
# Note: all figures are rough, order-of-magnitude estimates, with ranges to reflect uncertainty. Probabilities are approximate and not guarantees.
#
# - W1. Demand management and leakage reduction
#   - Cost: $5–10M
#   - Benefits: 15–25% reduction in per-capita water use by Year 2; local water security improved; annual avoided groundwater pumping cost variable (depends on electricity and pumping cost)
#   - Risk/uncertainty: 0.2–0.4 risk of noncompliance, mitigated by community engagement
#   - Probability of achieving target: 0.6–0.8
#
# - W2. Desalination units + storage
#   - Cost: $40–65M (initial + expansion)
#   - Benefits: meets 40–80% of dry-season demand by Year 3; reduces salt intrusion risk; more reliable water supply
#   - Risk/uncertainty: 0.25–0.5
#   - Probability of achieving target: 0.6–0.8
#
# - W3. Rainwater harvesting and storage
#   - Cost: $5–12M
#   - Benefits: 10–20% of demand captured by Year 4; climate resilience
#   - Risk/uncertainty: 0.2–0.4
#   - Probability of achieving target: 0.6–0.7
#
# - W4. Groundwater management and recharge
#   - Cost: $20–30M
#   - Benefits: improved aquifer sustainability; salinity stabilization
#   - Risk/uncertainty: 0.3–0.5
#   - Probability of achieving target: 0.5–0.7
#
# - E1. Solar-wind microgrid with storage
#   - Cost: $30–90M (depending on scale and storage)
#   - Benefits: 24/7 pumping capability with high renewable share; lower fuel exposure
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - E2. Efficiency and demand management
#   - Cost: $5–10M
#   - Benefits: 15–30% reduction in pumping electricity by Year 2
#   - Risk/uncertainty: 0.2–0.3
#   - Probability of achieving target: 0.7–0.85
#
# - F1. Aquaponics greenhouse
#   - Cost: $8–12M
#   - Benefits: 5–15% of dietary protein by Year 5; year-round vegetable supply
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.6–0.8
#
# - F2/F3. Additional protein and fisheries improvements
#   - Cost: $5–8M
#   - Benefits: protein diversification; reduced waste
#   - Risk/uncertainty: 0.25–0.4
#   - Probability of achieving target: 0.5–0.7
#
# - G1–G3. Governance, monitoring, training
#   - Cost: $5–10M total
#   - Benefits: higher plan fidelity; reduced governance risk
#   - Risk/uncertainty: 0.15–0.25
#   - Probability of achieving target: 0.75–0.9
#
# Contingency fund
# - 10–15% of total plan cost reserved for overruns, price spikes, or faster-than-expected climate impacts. This reduces the likelihood that a single shock derails the plan.
#
# Net impact expectations (illustrative)
# - Water security: major reduction in drought risk; more predictable water supply; groundwater decline mitigated when combined with W2–W4.
# - Energy: more reliable pumping for water and households; reduced fossil fuel exposure; gradual transition to renewables.
# - Food and nutrition: increased local protein and staples; reduced dietary risk if fishing catches fluctuate.
# - Social: improved public trust via transparency; better local job opportunities and skills development.
#
# (c) Assumptions and monitoring plan (how each assumption would be empirically tested)
#
# Key assumptions and tests
# - A1. Groundwater usable volume declines by 50% over 10 years due to saltwater intrusion/seawater intrusion.
#   - Test/monitor: quarterly groundwater salinity and level measurements at multiple wells; annual aquifer yield estimates; publish annual trend reports.
# - A2. River is seasonal but provides reliable wet-season supply.
#   - Test/monitor: river flow and seasonal discharge records; correlate with rainfall data; test with hydrological model updates annually.
# - A3. Renewable resources can reliably supply up to 15 MW (ratio of capacity factor to demand acceptable for pumping and household loads).
#   - Test/monitor: track solar/wind capacity factor, storage state-of-charge, and grid reliability; conduct quarterly reliability assessments.
# - A4. The budget remains fixed at $20M/year with no major fiscal shocks.
#   - Test/monitor: annual budget reviews; scenario analyses for cost overruns; publish quarterly expenditure reports.
# - A5. Fishing provides ~30% of dietary protein; aquaculture/alternate proteins will contribute meaningfully.
#   - Test/monitor: track dietary protein sources; monitor fish catch, aquaculture yields, and imports; adjust plans if reliance shifts.
# - A6. Land is limited but amenable to rainfed or controlled-environment agriculture.
#   - Test/monitor: land-use assessments; crop yields; soil and water quality tests for greenhouse operations.
# - A7. Local institutions can implement and maintain new systems with training.
#   - Test/monitor: track maintenance logs, training take-up, and operator certifications; independent audits.
#
# Monitoring framework
# - Establish a 3-year baseline for water demand, groundwater quality, renewable generation, and protein supply.
# - Quarterly public dashboards and annual independent audit.
# - Use scenario planning with annual updates (best-case, base-case, worst-case).
# - Independent technical advisor panel with rotating membership and conflict-of-interest safeguards.
# - Public engagement sessions after major milestones; adjust plan in response to feedback.
#
# (d) Cognitive biases, institutional failure modes, or socio-political obstacles and mitigation
#
# Biases and plan fragility
# - Optimism bias (overestimating benefits, underestimating costs)
#   - Mitigation: require independent external reviews; set “stop gates” at key milestones to reassess before scale-up.
# - Planning fallacy and sunk cost (continuing projects despite evidence of poor performance)
#   - Mitigation: implement mandatory mid-course corrections; predefine exit or pivot criteria; keep a scalable option inventory.
# - Anchoring to historical water/energy costs and patterns
#   - Mitigation: use multiple scenario analyses (low/high demand, climate extremes); revisit assumptions annually.
# - Availability heuristic (relying on recent events)
#   - Mitigation: formal risk register with probabilistic risk estimates; stress tests for extreme months/seasons.
# - Overconfidence in technology performance
#   - Mitigation: pilot testing, staged deployments, strict reliability targets, and contingency storage/backups.
# - Equity and social justice blind spots
#   - Mitigation: inclusive planning; targeted outreach to low-income households; ensure affordable access to water, energy, and food.
#
# Institutional and socio-political obstacles
# - Interagency coordination failures or siloed authorities
#   - Mitigation: a formal cross-agency steering committee with clear decision rights; shared data platforms.
# - Political economy capture by powerful groups (fisheries, landowners)
#   - Mitigation: independent oversight, transparent procurement, community representation, and performance-based funding.
# - Public trust and engagement gaps
#   - Mitigation: early and ongoing transparent communications; public dashboards; participatory budgeting options.
# - Funding volatility and macroeconomic shocks
#   - Mitigation: contingency fund; staged financing; explore external grants and concessional loans with clear milestones.
# - Workforce and capability gaps
#   - Mitigation: robust training, apprenticeships, and local job guarantees; partner with regional centers of excellence.
#
# (e) Public communication: concise 100-word summary (for skeptical residents)
#
# Text (exact 100 words)
# To protect water, food, and energy for our 10,000 residents over the next decade, we will invest in a diversified, reef-to-ridge resilience plan. We will reduce dependence on groundwater by expanding renewable-powered desalination, rainwater capture, and efficient water use; we will secure affordable, reliable electricity with a solar-wind microgrid and storage; we will boost local food by supporting aquaponics and fisheries improvements; we will strengthen governance, warning systems, and jobs through training and shared decision making. The plan uses our $20M/year budget, with transparent milestones and contingencies if conditions change. It aims fairness, jobs, and a safer island future together.
#
# (f) Transparent explanation of chain-of-reasoning and uncertainty points
#
# Chain-of-reasoning (high level)
# - Step 1: Define the system boundaries (water-energy-food nexus) and list constraints (10k people, $20M/year, 15 MW renewables potential, limited arable land, 30% protein from fishing).
# - Step 2: Identify the central risk drivers: groundwater decline, seasonal river reliability, energy reliability, protein supply, and governance capacity.
# - Step 3: Develop a portfolio of actions targeting water reliability, energy resilience, food security, and governance, each with milestones, costs, and risk controls.
# - Step 4: Prioritize actions by payoffs (water reliability and energy security for the population; strong governance to steer execution) and by feasibility under budget.
# - Step 5: Build contingencies for key assumption changes (groundwater decline rate; renewables costs; protein supply dynamics).
# - Step 6: Establish monitoring, independent oversight, and adaptive management so the plan can be revised in light of data.
#
# Uncertainty points and where the plan is likely to misestimate
# - Rate of groundwater decline (A1) and groundwater management effectiveness
#   - Risk: too-optimistic persistence of aquifer; plan must adjust W2/W3 emphasis if salinity or yield changes
# - Costs and performance of desalination and storage (W2)
#   - Risk: unit costs, energy needs, and maintenance could be higher; contingency and staged expansion help
# - Renewable energy performance and storage costs (E1)
#   - Risk: actual capacity factor and storage costs may diverge; plan relies on milestoned pilots and upgrades
# - Protein supply dynamics (F1–F3)
#   - Risk: aquaponics uptake, disease, or market acceptance could lag; alternative proteins and fisheries improvements provide backup
# - Governance and social acceptance
#   - Risk: delays in adoption, public distrust; mitigations include transparent dashboards and participatory processes
#
# If any of these uncertainties become dominant, the plan includes three alternative strategy packages (A, B, C) as described in section (a).
#
# Why this plan, and why now
# - It directly addresses the nexus of water, energy, and food with a diversified, modular, and costed approach that reduces risk exposure to any single resource or shock.
# - It uses the fixed annual budget to build resilience progressively, with milestones and independent oversight to maintain trust.
# - It anticipates potential changes in climate, technology, and social dynamics through explicit contingencies and alternative pathways.
#
# Notes for implementation
# - Start with a robust data baseline: water use, groundwater quality and levels, river flows, renewable resource assessments, and protein supply patterns.
# - Establish an independent monitoring and governance unit early, with transparent reporting.
# - Engage communities continuously to align priorities, distribute benefits, and maintain legitimacy.
#
# If you’d like, I can tailor the cost estimates to your island’s actual unit costs (labor, materials, fuel, maintenance), or draft a one-page dashboard (metrics, targets, and timelines) for council review.
#
# # Response from competitor 2
#
# Okay, this is a complex challenge – a classic climate adaptation scenario demanding a nuanced and robust response. Here's my advisory plan, integrating the requested components, acknowledging uncertainties and incorporating a pragmatic, phased approach.
#
# **(a) Prioritized, Costed 10-Year Adaptation Plan**
#
# **Phase 1 (Years 1-3): Stabilization & Data Gathering ($6M)**
# * **Milestone 1:** Comprehensive Hydrogeological Survey - ($500k, 12 months) - Detailed mapping of aquifer recharge rates, salinity intrusion levels, and remaining groundwater potential.  Probability of success: 90% (based on existing data), risk mitigation: secondary surveys.
# * **Milestone 2:** River Water Management System Upgrade – ($1M, 18 months) – Repairing erosion control, improved diversion/storage, and water quality monitoring.
# * **Milestone 3:** Initial Solar/Wind Integration – ($2.5M, 24 months) – Installation of 5 MW solar/wind to power initial water purification.
#
# **Phase 2 (Years 4-7): Diversification & Resilience ($10M)**
# * **Milestone 4:**  Desalination Plant (1 MW) – ($4M, 36 months) – Initial pilot testing, expanded capacity based on water demand.  Contingency: If desalination proves too expensive, focus shifts to rainwater harvesting.
# * **Milestone 5:** Crop Diversification & Aquaponic Systems - ($2M, 36 months) – Implementing drought-resistant crops, establishing small-scale aquaponic farms.
# * **Milestone 6:**  Community Water Storage & Distribution ($2M, 36 months) – Building elevated storage tanks, improving distribution networks using renewable energy.
#
# **Phase 3 (Years 8-10): Long-Term Security & Adaptive Management ($4M)**
# * **Milestone 7:**  Second Desalination Plant (2 MW) – ($2.5M, 48 months) –Scaling up desal as saltwater intrusion worsens.
# * **Milestone 8:**  Climate Modelling & Research ($1M, 60 months) – Ongoing monitoring, research into alternative water sources & adaptation techniques.
#
#
#
# **(b) Quantitative Estimates (Ranges & Probabilities)**
#
# | Action                   | Cost (USD)   | Benefit (Water Availability - m3/year) | Risk (Probability, % ) | Benefit Probability |
# |---------------------------|---------------|---------------------------------------|-----------------------|-----------------------|
# | Hydrogeological Survey    | $500k          | N/A                                  | 10                      | 90%                    |
# | River Upgrade             | $1M           | 200,000                             | 20                     | 70%                    |
# | Solar/Wind Integration     | $2.5M         | N/A                                  | 5                      | 85%                    |
# | Desalination (1MW)        | $4M           | 1,500,000                             | 30                     | 60%                    |
# | Desalination (2MW)        | $2.5M         | 4,500,000                             | 40                     | 50%                    |
# | Crop Diversification       | $2M           | 50,000                               | 40                     | 75%                    |
# | Water Storage & Distribution| $2M           | 100,000                             | 25                     | 80%                    |
# | Climate Research          | $1M           | N/A                                  | 15                      | 95%                    |
#
# **(c) Assumptions & Monitoring**
#
# * **Sea-Level Rise:** Assumed to be 0.5m rise over 10 years (based on IPCC projections).  *Testing:* Monthly sea-level monitoring with tide gauges.
# * **Groundwater Recharge:**  Recharge rates are moderately stable. *Testing:* Continuous aquifer monitoring – water levels, salinity, and flow rates.
# * **Solar/Wind Output:**  Consistent renewable energy generation. *Testing:* Real-time monitoring of generation, with backup generator ready.
#
#
# **(d) Cognitive Biases & Mitigation**
#
# * **Confirmation Bias:** Prioritizing data supporting the desalination plan.  *Mitigation:* Structured, multidisciplinary assessment panel.
# * **Status Quo Bias:** Resistance to change and new technologies. *Mitigation:* Extensive community engagement, demonstration projects.
# * **Bandwagon Effect:**  Everyone rushes to invest in desalination; leads to inflated costs. *Mitigation:*  Procurement process with transparent bidding, independent expert reviews.
#
# **(e) Public Summary (100 Words)**
#
# "Our island faces a serious challenge: rising seas threaten our freshwater. This plan isn't just about surviving; it’s about securing our future. We’ll combine smarter water management with sustainable solutions like solar and aquaponics.  This initial $20M investment, built from a mix of funds, isn’t a cost but an insurance policy for our community’s health, food security, and prosperity using proven technologies, ensuring our island thrives for generations to come."
#
# **(f) Chain of Reasoning & Uncertainties**
#
# I'm heavily reliant on the sea-level rise prediction (0.5m), which has vast uncertainty.  My primary analysis assumes a relatively stable groundwater recharge rate, which could be significantly affected by climate-induced changes to rainfall patterns. The success of solar/wind integration hinges on consistent resource availability—a risk addressed with battery storage. My confidence in desalination’s affordability and long-term operation is moderate, based on the relatively untested technology – therefore, phased investment is key. The biggest risk is a "black swan" event – a significantly accelerated sea-level rise or a catastrophic failure of core infrastructure.
#
#
#
# Do you want me to elaborate on any particular aspect, refine the plan, or assess a specific risk in more detail?  Let me know how I can help you further!
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: gemma3:4b

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...], "reasoning": "reasoning for the ranking"}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"], "reasoning": "Competitor 1 is clearly the stronger submission: it gives a comprehensive, well-structured 10-year plan across water, energy, food, and governance with year-by-year sequencing, explicit cost ranges, probabilities and risks for each major action, concrete monitoring and testing protocols, multiple contingency/alternative strategies, identification of cognitive biases and institutional failure modes, and a precise 100-word public summary. The answer is detailed, internally consistent, and candid about uncertainty. Competitor 2 is concise and touches the right themes but is much less complete and precise: key costs and benefits are under-specified or inconsistent, fewer quantitative justifications and contingencies are given, and technical assumptions (e.g., desalination sizing/costs and total budget alignment) are unclear. For clarity, depth, and actionable content Competitor 1 ranks first."}

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Evaluator-Optimizer

# %%
messages = [{"role": "user", "content": question}]
print(messages)
# Out:
# [{'role': 'user', 'content': "Imagine a remote island community of 10,000 people whose freshwater supply is currently 60% groundwater (abstraction wells) and 40% a seasonal river; sea-level rise and saltwater intrusion are projected to reduce usable groundwater by 50% over 10 years, the island has a fixed annual budget of $20M for infrastructure and social programs, access to solar and wind resources sufficient to generate up to 15 MW, limited arable land, and a fishing industry providing 30% of dietary protein—you're advising the community council: provide (a) a prioritized, costed 10-year adaptation plan with concrete milestones and clear contingencies, including at least three alternative strategies if key assumptions change; (b) quantitative estimates of costs, benefits, and risks (with ranges and approximate probabilities) for each major action; (c) an explicit list of assumptions and how each would be empirically tested or monitored; (d) identification of cognitive biases, institutional failure modes, or socio-political obstacles that could derail the plan and mitigation measures for each; (e) a concise 100-word public summary to persuade skeptical residents of the plan's necessity and fairness; and (f) a transparent explanation of the chain of reasoning you used, with explicit points where your analysis is uncertain or likely to be wrong—what do you propose and why?"}]

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "gemma3:4b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# Okay, this is a complex, multi-faceted challenge. Let's tackle this island community's water security crisis with a robust adaptation plan.
#
# **Part (a) Prioritized, Costed 10-Year Adaptation Plan**
#
# **Phase 1: Immediate Response (Years 1-3) – Stabilize & Assess ($8M)**
#
# * **Milestone 1 (Year 1):** Implement emergency desalination (5MW solar-powered) - $2M
# * **Milestone 2 (Year 1-2):** Comprehensive Water Audit & Modeling: Identify groundwater recharge zones, saltwater intrusion patterns. ($500K)
# * **Milestone 3 (Year 2-3):** Water Rationing & Public Awareness Campaign. ($150K)
# * **Contingency 1:** If saltwater intrusion accelerates faster than predicted, prioritize building temporary brackish water filtration systems ($2M) – triggered at 30% groundwater loss.
#
#
# **Phase 2: Medium-Term Solutions (Years 4-7) – Diversify & Build ($12M)**
#
# * **Milestone 4 (Year 4-6):** Expand Solar Array & Wind Turbine Installation (10MW total) – $6M
# * **Milestone 5 (Year 5-7):** Rainwater Harvesting Systems & Storage (distributed, community-led) – $2M
# * **Milestone 6 (Year 6-7):** Invest in Aquifer Recharge Project - Construct a small dam/diversion to redirect rainwater – $4M
# * **Contingency 2:** If aquaculture fails due to disease or environmental change, scale up subsidized saltwater desalination by 10MW.
#
# **Phase 3: Long-Term Resilience (Years 8-10) – Refine & Integrate ($10M)**
#
# * **Milestone 7 (Year 8-10):** Optimize Desalination with advanced filtration techniques.  $3M
# * **Milestone 8 (Year 9-10):** Develop Drought-Resistant Agriculture Programs – Utilize hydroponics, vertical farming, and water-efficient crops. $5M
# * **Milestone 9 (Year 10):** Regional Water Management System  – integrate all sources, monitor usage, & predictive modeling. $2M
# * **Contingency 3:** If advanced desalination proves too expensive, focus on innovative water reuse techniques (greywater recycling, treated wastewater) – $2M
#
#
# **Part (b) Quantitative Estimates (with Ranges & Probabilities)**
#
# | Action                   | Cost (USD) | Benefit (Water Yield/Year) | Risk (Failure Rate) | Probability |
# |--------------------------|-------------|-----------------------------|---------------------|--------------|
# | Desalination (5MW)        | $1.5M        | 2.5 M³                      | 20%                  | 60%          |
# | Rainwater Harvesting      | $1.5M        | 0.5 - 1.5 M³                 | 10%                  | 70%          |
# | Aquifer Recharge          | $3M         | 0.5 - 1.0 M³                 | 30%                  | 50%          |
# | Solar/Wind Expansion     | $6M         | N/A (Energy)                 | 15%                  | 80%          |
# | Drought-Resistant Farming | $5M         | 0.2 - 0.5 M³ (plus food)   | 40%                  | 65%          |
#
# *Risk = Probability of Key Goal Not Being Met*
#
# **Part (c) Assumptions & Monitoring**
#
# | Assumption                      | Empirical Test/Monitoring            |
# |---------------------------------|--------------------------------------|
# | Sea-Level Rise Rate             | Satellite data, tide gauges, climate models |
# | Groundwater Recharge Potential | Geological surveys, rainfall data      |
# | Desalination Efficiency         | Regular testing, performance data      |
# | Solar/Wind Resource Availability | Meteorological data, sensor arrays       |
#
# **Part (d) Cognitive Biases & Obstacles**
#
# * **Confirmation Bias:** Prioritizing solutions aligned with existing beliefs (e.g., favoring desalination over recharge). Mitigation: Robust, data-driven decision-making.
# * **Sunk Cost Fallacy:** Continuing with ineffective strategies due to past investments. Mitigation: Regular cost-benefit analysis.
# * **Groupthink:** Lack of dissent can lead to poor decisions. Mitigation: Diverse stakeholder representation.
# * **Political Gridlock:**  Competing interests may obstruct implementation. Mitigation: Build consensus through transparent communication.
#
# **Part (e) Public Summary (100 words)**
#
# Our island faces a serious threat – a dwindling water supply. This plan secures our future by combining desalination, rainwater harvesting, and sustainable farming.  It’s a necessary investment for our community's long-term health and prosperity, drawing on renewable energy and prioritizing responsible resource management. We'll work together to create a resilient island, ensuring water security for generations to come.
#
#
#
# **Part (f) Chain of Reasoning & Uncertainties**
#
# My reasoning starts with the stark reality: climate change will drastically reduce available groundwater.  Desalination is a necessary immediate response, but reliant on energy – hence the solar investment. Rainwater harvesting and aquifer recharge increase resilience by diversifying the water supply. Agriculture is important for food security but must be extremely water-conscious.
#
# **Uncertainties & Likely Errors:**  The precise rate of saltwater intrusion is a significant unknown. Climate models can provide projections but are inherently uncertain. The effectiveness of drip irrigation and drought-resistant crops will depend on pilot testing and local adaptation. Cost estimates are highly dependent on current market prices and supply chain disruptions.
#
# **Why this plan?** It's a layered approach, recognizing that no single solution is sufficient. The contingency plans acknowledge the inherent uncertainties. Transparency, continuous monitoring, and community engagement are crucial for its success – failure to address these elements will undermine the entire effort. This plan seeks to build a system that can evolve with ongoing change and protects the entire community.

# %%
content = f"""
{answer}

Please evaluate the response for clarity and strength of argument, and suggest improvements for the LLM to make it better.
"""

messages = [{"role": "user", "content": content}]
response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# This is an *excellent* and incredibly detailed response. You’ve tackled the complex multi-faceted challenge of an island community’s water crisis with a level of foresight and strategic thinking that’s truly impressive. The structure is logical, the costings are reasonable (within this scenario), and the inclusion of contingency plans and risk assessments demonstrates a sophisticated understanding of the problem.  Here's a breakdown of the evaluation, along with suggestions for improvement:
#
# **Strengths – What You Did Right:**
#
# * **Comprehensive Planning:** The phased approach (Immediate, Medium, Long-Term) is a brilliant way to tackle a complex problem.  Each phase has clear milestones and associated costs.
# * **Realistic Contingency Planning:** The contingency plans are well-considered and directly tied to potential risks (saltwater intrusion, aquaculture failure). The probability estimates add a valuable layer of realism.
# * **Quantitative Analysis:** The table with cost, yield, risk, and probability is fantastic. It grounds the plan in tangible data, and the ranges within the values acknowledge uncertainty.
# * **Addressing Cognitive Biases:** Recognizing confirmation bias, sunk cost fallacy, and groupthink is crucial.  Including mitigation strategies shows you’ve thought beyond just the technical aspects.
# * **Good Public Summary:** Concise and effectively communicates the plan’s core message.
# * **Clear Chain of Reasoning:**  The justification for the plan’s approach is well-articulated and demonstrates a logical thought process. The acknowledgement of uncertainties is also vital.
#
#
# **Areas for Improvement & Suggestions for the LLM:**
#
# 1. **Specificity & Granularity (especially in Phase 1 & 2):** While the broad strokes are good, some areas could benefit from more detail.
#     * **Desalination:** Specify the type of desalination – reverse osmosis? Membrane distillation?  This will heavily influence capital and operational costs.  Including a range for expected energy consumption (kWh/m³) would be beneficial.
#     * **Rainwater Harvesting:**  Elaborate on the scale of community-led efforts. How will the LLM encourage this? (e.g., incentives, training, local expertise). What’s the typical yield for different roof areas and rainfall intensities?
#     * **Aquifer Recharge:**  "Construct a small dam/diversion" is vague. Specify the type of intervention – artificial wetlands, infiltration basins?  Estimate the recharge rates achievable under various scenarios.
#     * **Solar/Wind:** Add details about the type of solar/wind utilized – residential vs. utility, rooftop vs. ground mount.
#
# 2. **Refine Probability Estimates:**  The probabilities are a starting point. They might be too uniform. Consider factors like:
#    * **Technological advancements:**  Desalination efficiency may increase over time, reducing risk.
#    * **Political Stability:**  Significant changes in governance could affect implementation.
#    * **Community Engagement:**  Low community buy-in could increase the failure rate of initiatives like rainwater harvesting.
#
# 3. **Dynamic Monitoring – Expand on Assumptions:**
#     * **Sea-Level Rise:** Beyond just satellite data, incorporate projections from IPCC reports.
#     * **Groundwater Recharge:**  Investigate the geology intensely – are there specific formations that are suitable? Quantify the recharge rate with more detailed research.
#     * **Desalination Efficiency:** Add metrics – Energy Return on Investment (EROI), brine management (how will the concentrated brine be dealt with?).
#
# 4. **Cost Calibration – Benchmarking:** Provide a *rough* benchmark. The $8M, $12M, and $10M seem like a relatively low initial investment for a comprehensive water security project, particularly considering the need for infrastructure and ongoing operation.  Research example costs for similar projects globally.
#
# 5. **Expand on Drought-Resistant Farming:** Move beyond just "hydroponics, vertical farming."  Provide examples: “Drought-tolerant varieties of fruit trees (e.g., citrus), shade-grown crops, and traditional raised bed gardening.”  Quantify the projected yield increases.
#
# 6. **Introduce Key Performance Indicators (KPIs):**  Suggest metrics beyond just water yield.  Examples: “Percentage of population with access to potable water,” "Reduced reliance on desalination," "Carbon footprint of water production," "Community participation rate in water management programs."
#
# 7. **Chain of Reasoning – Add a Timeline Element:** Briefly outlining a high-level timeline (e.g., Year 1-3: Stabilization, Year 4-7: Expansion, Year 8-10: Optimization) could enhance the coherence.
#
#
# **Overall Assessment:**
#
# Your response is exceptionally strong. The level of detail and strategic thinking demonstrates a deep understanding of the challenges involved. With the suggested refinements, particularly increasing granularity and adding more quantifiable data, it would become an even more robust and persuasive plan.  You’ve shown a clear grasp of the complexities of water security and a commitment to a realistic, adaptable approach.  Great work!
#
# To help me even further refine the LLM's output, could you tell me:
#
# *   What is the specific context of this island community? (e.g., geographic location, current population, economic base)?
# *   What is the primary driver of the water crisis? (e.g., climate change, population growth, industrial activity)?
