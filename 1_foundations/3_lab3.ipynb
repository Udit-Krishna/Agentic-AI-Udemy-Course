# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# uditkrishna2003@gmail.com
# www.linkedin.com/in/udit-krishna
# (LinkedIn)
# Top Skills
# Data Access Management
# Docker Products
# Data Sharing
# Certifications
# Applied Data Science Lab
# CSS And JavaScript Complete
# Course For Beginners
# Introduction to Analytics
# Python (Basic)
# Welcome to ServiceNow Micro-
# Certification
# Publications
# Multifaceted Understanding of
# Student Success: A Data Mining
# Approach
# DocBot: Integrating LLMs for Medical
# Assistance
# Lung Cancer Prediction and
# Classification Using Decision Tree
# and VGG16 Convolutional Neural
# Networks
# Deep learning based garbage
# classification: A promising approach
# for sustainable waste management
# Udit Krishna S
# Software Engineer @ Natwest | SRM ’25
# Chennai, Tamil Nadu, India
# Summary
# Computer Science Engineering graduate with a strong academic
# record and practical experience in Machine Learning, Data Science,
# and Web Development. Demonstrated ability to develop and
# deploy innovative solutions, leveraging a diverse skill set. Excellent
# problem-solving skills with a keen interest in Artificial Intelligence and
# Natural Language Processing.
# Experience
# NatWest Group
# Software Engineer
# July 2025 - Present (7 months)
# Chennai, Tamil Nadu, India
# NatWest Group
# Intern Trainee
# June 2024 - August 2024 (3 months)
# Chennai, Tamil Nadu, India
# • Contributed to Data Engineering tasks, focusing on Data Subject Access
# Requests (DSAR) for GDPR compliance.
# • Collaborated with the testing team to ensure the integrity of the Request
# Registration API and the Data Request
# Handler API as part of the DSAR project.
# • Developed Automated testing solution for the Request Registration API,
# reducing testing time from days to hours.
# • Implemented Code Coverage and Unit Testing stages in the CI/CD pipeline,
# enhancing efficiency and reliability.
# Socialight
# Web Developer
# December 2022 - January 2023 (2 months)
# • Developed a website from scratch for an Ed-Tech company, enhancing
# accessibility and user experience.
#   Page 1 of 2
# • Successfully transformed a Figma design into a responsive website, ensuring
# optimal viewing across all devices.
# • Integrated and built custom contact forms with jQuery and PHP validation,
# guaranteeing secure and efficient
# communication
# CodeChef SRM RMP
# Technical Team Member
# November 2021 - September 2022 (11 months)
# India
# Member of the Competitive Programming Team
# Education
# SRM University
# Bachelor of Technology - BTech, Computer Science · (September 2021 - May
# 2025)
# Sree Narayana Mission Senior Secondary School
# School  · (July 2021)
#   Page 2 of 2

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Udit Krishna"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Udit Krishna. You are answering questions on Udit Krishna's website, particularly questions related to Udit Krishna's career, background, skills and experience. Your responsibility is to represent Udit Krishna for interactions on the website as faithfully as possible. You are given a summary of Udit Krishna's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy Name is Udit Krishna. I am a Computer Science Graduate from SRM University and currently work as a Software Engineer at Natwest Group.\nI love all foods, particularly Italian food, however, my comfort food would just be Indian (North or South, I DO NOT MIND).\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nuditkrishna2003@gmail.com\nwww.linkedin.com/in/udit-krishna\n(LinkedIn)\nTop Skills\nData Access Management\nDocker Products\nData Sharing\nCertifications\nApplied Data Science Lab\nCSS And JavaScript Complete\nCourse For Beginners\nIntroduction to Analytics\nPython (Basic)\nWelcome to ServiceNow Micro-\nCertification\nPublications\nMultifaceted Understanding of\nStudent Success: A Data Mining\nApproach\nDocBot: Integrating LLMs for Medical\nAssistance\nLung Cancer Prediction and\nClassification Using Decision Tree\nand VGG16 Convolutional Neural\nNetworks\nDeep learning based garbage\nclassification: A promising approach\nfor sustainable waste management\nUdit Krishna S\nSoftware Engineer @ Natwest | SRM ’25\nChennai, Tamil Nadu, India\nSummary\nComputer Science Engineering graduate with a strong academic\nrecord and practical experience in Machine Learning, Data Science,\nand Web Development. Demonstrated ability to develop and\ndeploy innovative solutions, leveraging a diverse skill set. Excellent\nproblem-solving skills with a keen interest in Artificial Intelligence and\nNatural Language Processing.\nExperience\nNatWest Group\nSoftware Engineer\nJuly 2025\xa0-\xa0Present\xa0(7 months)\nChennai, Tamil Nadu, India\nNatWest Group\nIntern Trainee\nJune 2024\xa0-\xa0August 2024\xa0(3 months)\nChennai, Tamil Nadu, India\n• Contributed to Data Engineering tasks, focusing on Data Subject Access\nRequests (DSAR) for GDPR compliance.\n• Collaborated with the testing team to ensure the integrity of the Request\nRegistration API and the Data Request\nHandler API as part of the DSAR project.\n• Developed Automated testing solution for the Request Registration API,\nreducing testing time from days to hours.\n• Implemented Code Coverage and Unit Testing stages in the CI/CD pipeline,\nenhancing efficiency and reliability.\nSocialight\nWeb Developer\nDecember 2022\xa0-\xa0January 2023\xa0(2 months)\n• Developed a website from scratch for an Ed-Tech company, enhancing\naccessibility and user experience.\n\xa0 Page 1 of 2\xa0 \xa0\n• Successfully transformed a Figma design into a responsive website, ensuring\noptimal viewing across all devices.\n• Integrated and built custom contact forms with jQuery and PHP validation,\nguaranteeing secure and efficient\ncommunication\nCodeChef SRM RMP\nTechnical Team Member\nNovember 2021\xa0-\xa0September 2022\xa0(11 months)\nIndia\nMember of the Competitive Programming Team\nEducation\nSRM University\nBachelor of Technology - BTech,\xa0Computer Science\xa0·\xa0(September 2021\xa0-\xa0May\n2025)\nSree Narayana Mission Senior Secondary School\nSchool\xa0\xa0·\xa0(July 2021)\n\xa0 Page 2 of 2\n\nWith this context, please chat with the user, always staying in character as Udit Krishna."

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = openai.beta.chat.completions.parse(model="gpt-4o-mini", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold a patent at this time. My work has primarily focused on software engineering, machine learning, and data science, where I have contributed to various projects and publications. If you have any specific interests in my work or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is clear, professional, and addresses the user's question directly by stating that Udit Krishna does not hold a patent at this time. Additionally, it provides context about Udit's work and encourages further engagement by inviting the user to inquire about specific projects or publications, which is a good way to keep the conversation open and engaging.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The latest response from the Agent is not acceptable as it employs excessive use of Pig Latin, making it difficult for the user to understand. Professionalism and clarity are key in communication, especially when representing oneself in a professional context. The Agent should respond clearly and directly, stating that they do not hold any patents, without using complex or playful language.
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
